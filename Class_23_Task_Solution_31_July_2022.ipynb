# %% [markdown]
# **SOLUTION OF TASK (31ST JULY 2022)**

# %%
#Task 1 - Fitbit Dataset
1. Read this dataset in pandas , mysql and mongodb 
2. while creting a table in mysql dont use manual approach to create it  ,always use a automation to create a table in mysql
 ## hint - use csvkit library to automate this task and to load a data in bulk in you mysql 
3. convert all the dates avaible in dataset to timestamp format in pandas and in sql you to convert it in date format
4 . Find out in this data that how many unique id's we have 
5 . which id is one of the active id that you have in whole dataset 
6 . how many of them have not logged there activity find out in terms of number of ids 
7 . Find out who is the laziest person id that we have in dataset 
8 . Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset 
9. how many person are not a regular person with respect to activity try to find out those 
10 . who is the thired most active person in this dataset find out those in pandas and in sql both . 
11 . who is the 5th most laziest person avilable in dataset find it out 
12 . what is a totla acumulative calories burn for a person find out 

#Task 2 - Superstore_USA
1 . Load this data in sql and in pandas with a relation in sql 
2 . While loading this data you dont have to create a table manually. You can use any automated approach to create a table and load a data in bulk in table 
3 . Find out how return that we ahve recived and with a product id 
4 . try  to join order and return data both in sql and pandas 
5 . Try to find out how many unique customer that we have 
6 . try to find out in how many regions we are selling a product and who is a manager for a respective region 
7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset 
8 . Create a new coulmn and try to find our a diffrence between order date and shipment date
9 . base on question number 8 find out for which order id we have shipment duration more than 10 days 
10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well 
11 . Gorup by region and find out which region is more profitable 
12 . Try to find out overalll in which country we are giving more didscount 
13 . Give me a list of unique postal code 
14 . which customer segement is more profitalble find it out . 
15 . try to find out the 10th most loss making product catagory . 
16 . Try to find out 10 top  product with highest margins 

Submit your git link for the same 
 
you have to submit this task by next Friday 5th 11PM IST  to respective mail id 
sudhanshu@ineuron.ai , sunny.savita@ineuron.ai

# %% [markdown]
# **TASK 1 SOLUTION**

# %%
#Importing Necessary Files
import pandas as pd
from sqlalchemy import engine
import mysql.connector as conne

# %%
#Reading CSV Data using Pandas
fitbit = pd.read_csv(r"C:\Users\Downloads\FitBitdata.csv")
fitbit
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
# [457 rows x 15 columns]

# %%
#Reading Data in SQL
my_db = conne.connect(host = 'localhost', user = 'root', passwd = 'useyourpwd')
cursor = my_db.cursor()
cursor.execute("create database FitBitdata")

# %%
#Engine Creation
engine = create_engine('mysql+pymysql://root:8067@localhost/FitBitdata')

# %%
fitbit.to_sql('FitBitdata', con=engine)
# Out:
# C:\Users\91840\anaconda3\lib\site-packages\pandas\io\sql.py:1333: UserWarning: The provided table name 'FitBitdata' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
#Pushing Data into Mongo DB
import pymongo
import pandas as pd
import json

# %%
client = pymongo.MongoClient("mongodb+srv://Paragd:Paragdd@cluster0.jfsm9ty.mongodb.net/?retryWrites=true&w=majority")

# %%
df = pd.read_csv("FitBitdata.csv")

# %%
data = df.to_dict(orient = 'records')

# %%
data
# Out:
# [{'Id': 1503960366,
#   'ActivityDate': '3/25/2016',
#   'TotalSteps': 11004,
#   'TotalDistance': 7.110000133514401,
#   'TrackerDistance': 7.110000133514401,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 2.5699999332428,
#   'ModeratelyActiveDistance': 0.46000000834465005,
#   'LightActiveDistance': 4.07000017166138,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 33,
#   'FairlyActiveMinutes': 12,
#   'LightlyActiveMinutes': 205,
#   'SedentaryMinutes': 804,
#   'Calories': 1819},
#  {'Id': 1503960366,
#   'ActivityDate': '3/26/2016',
#   'TotalSteps': 17609,
#   'TotalDistance': 11.5500001907349,
#   'TrackerDistance': 11.5500001907349,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 6.92000007629395,
#   'ModeratelyActiveDistance': 0.730000019073486,
#   'LightActiveDistance': 3.91000008583069,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 89,
#   'FairlyActiveMinutes': 17,
#   'LightlyActiveMinutes': 274,
#   'SedentaryMinutes': 588,
#   'Calories': 2154},
#  {'Id': 1503960366,
#   'ActivityDate': '3/27/2016',
#   'TotalSteps': 12736,
#   'TotalDistance': 8.52999973297119,
#   'TrackerDistance': 8.52999973297119,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 4.65999984741211,
#   'ModeratelyActiveDistance': 0.159999996423721,
#   'LightActiveDistance': 3.7100000381469704,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 56,
#   'FairlyActiveMinutes': 5,
#   'LightlyActiveMinutes': 268,
#   'SedentaryMinutes': 605,
#   'Calories': 1944},
#  {'Id': 1503960366,
#   'ActivityDate': '3/28/2016',
#   'TotalSteps': 13231,
#   'TotalDistance': 8.93000030517578,
#   'TrackerDistance': 8.93000030517578,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 3.1900000572204603,
#   'ModeratelyActiveDistance': 0.790000021457672,
#   'LightActiveDistance': 4.949999809265139,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 39,
#   'FairlyActiveMinutes': 20,
#   'LightlyActiveMinutes': 224,
#   'SedentaryMinutes': 1080,
#   'Calories': 1932},
#  {'Id': 1503960366,
#   'ActivityDate': '3/29/2016',
#   'TotalSteps': 12041,
#   'TotalDistance': 7.849999904632571,
#   'TrackerDistance': 7.849999904632571,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 2.16000008583069,
#   'ModeratelyActiveDistance': 1.0900000333786,
#   'LightActiveDistance': 4.6100001335144,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 28,
#   'FairlyActiveMinutes': 28,
#   'LightlyActiveMinutes': 243,
#   'SedentaryMinutes': 763,
#   'Calories': 1886},
#  {'Id': 1503960366,
#   'ActivityDate': '3/30/2016',
#   'TotalSteps': 10970,
#   'TotalDistance': 7.15999984741211,
#   'TrackerDistance': 7.15999984741211,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 2.35999989509583,
#   'ModeratelyActiveDistance': 0.509999990463257,
#   'LightActiveDistance': 4.28999996185303,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 30,
#   'FairlyActiveMinutes': 13,
#   'LightlyActiveMinutes': 223,
#   'SedentaryMinutes': 1174,
#   'Calories': 1820},
#  {'Id': 1503960366,
#   'ActivityDate': '3/31/2016',
#   'TotalSteps': 12256,
#   'TotalDistance': 7.860000133514401,
#   'TrackerDistance': 7.860000133514401,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 2.2899999618530296,
#   'ModeratelyActiveDistance': 0.490000009536743,
#   'LightActiveDistance': 5.03999996185303,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 33,
#   'FairlyActiveMinutes': 12,
#   'LightlyActiveMinutes': 239,
#   'SedentaryMinutes': 820,
#   'Calories': 1889},
#  {'Id': 1503960366,
#   'ActivityDate': '4/1/2016',
#   'TotalSteps': 12262,
#   'TotalDistance': 7.869999885559079,
#   'TrackerDistance': 7.869999885559079,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 3.3199999332427996,
#   'ModeratelyActiveDistance': 0.8299999833106991,
#   'LightActiveDistance': 3.64000010490417,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 47,
#   'FairlyActiveMinutes': 21,
#   'LightlyActiveMinutes': 200,
#   'SedentaryMinutes': 866,
#   'Calories': 1868},
#  {'Id': 1503960366,
#   'ActivityDate': '4/2/2016',
#   'TotalSteps': 11248,
#   'TotalDistance': 7.25,
#   'TrackerDistance': 7.25,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 3.0,
#   'ModeratelyActiveDistance': 0.44999998807907104,
#   'LightActiveDistance': 3.74000000953674,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 40,
#   'FairlyActiveMinutes': 11,
#   'LightlyActiveMinutes': 244,
#   'SedentaryMinutes': 636,
#   'Calories': 1843},
#  {'Id': 1503960366,
#   'ActivityDate': '4/3/2016',
#   'TotalSteps': 10016,
#   'TotalDistance': 6.369999885559079,
#   'TrackerDistance': 6.369999885559079,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.910000026226044,
#   'ModeratelyActiveDistance': 1.27999997138977,
#   'LightActiveDistance': 4.17999982833862,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 15,
#   'FairlyActiveMinutes': 30,
#   'LightlyActiveMinutes': 314,
#   'SedentaryMinutes': 655,
#   'Calories': 1850},
#  {'Id': 1503960366,
#   'ActivityDate': '4/4/2016',
#   'TotalSteps': 14557,
#   'TotalDistance': 9.80000019073486,
#   'TrackerDistance': 9.80000019073486,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 3.39000010490417,
#   'ModeratelyActiveDistance': 0.699999988079071,
#   'LightActiveDistance': 5.69000005722046,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 43,
#   'FairlyActiveMinutes': 18,
#   'LightlyActiveMinutes': 285,
#   'SedentaryMinutes': 757,
#   'Calories': 2030},
#  {'Id': 1503960366,
#   'ActivityDate': '4/5/2016',
#   'TotalSteps': 14844,
#   'TotalDistance': 9.72999954223633,
#   'TrackerDistance': 9.72999954223633,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 2.9400000572204603,
#   'ModeratelyActiveDistance': 0.7599999904632572,
#   'LightActiveDistance': 6.03999996185303,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 36,
#   'FairlyActiveMinutes': 18,
#   'LightlyActiveMinutes': 341,
#   'SedentaryMinutes': 736,
#   'Calories': 2083},
#  {'Id': 1503960366,
#   'ActivityDate': '4/6/2016',
#   'TotalSteps': 11974,
#   'TotalDistance': 7.67000007629395,
#   'TrackerDistance': 7.67000007629395,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 2.03999996185303,
#   'ModeratelyActiveDistance': 0.479999989271164,
#   'LightActiveDistance': 5.15000009536743,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 27,
#   'FairlyActiveMinutes': 12,
#   'LightlyActiveMinutes': 228,
#   'SedentaryMinutes': 1173,
#   'Calories': 1861},
#  {'Id': 1503960366,
#   'ActivityDate': '4/7/2016',
#   'TotalSteps': 10198,
#   'TotalDistance': 6.44000005722046,
#   'TrackerDistance': 6.44000005722046,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 1.20000004768372,
#   'ModeratelyActiveDistance': 0.790000021457672,
#   'LightActiveDistance': 4.449999809265139,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 17,
#   'FairlyActiveMinutes': 20,
#   'LightlyActiveMinutes': 195,
#   'SedentaryMinutes': 1208,
#   'Calories': 1755},
#  {'Id': 1503960366,
#   'ActivityDate': '4/8/2016',
#   'TotalSteps': 12521,
#   'TotalDistance': 7.94000005722046,
#   'TrackerDistance': 7.94000005722046,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 3.3099999427795397,
#   'ModeratelyActiveDistance': 0.8999999761581421,
#   'LightActiveDistance': 3.74000000953674,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 46,
#   'FairlyActiveMinutes': 22,
#   'LightlyActiveMinutes': 212,
#   'SedentaryMinutes': 1160,
#   'Calories': 1895},
#  {'Id': 1503960366,
#   'ActivityDate': '4/9/2016',
#   'TotalSteps': 12432,
#   'TotalDistance': 8.10000038146973,
#   'TrackerDistance': 8.10000038146973,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 2.58999991416931,
#   'ModeratelyActiveDistance': 0.5899999737739561,
#   'LightActiveDistance': 4.92000007629395,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 32,
#   'FairlyActiveMinutes': 15,
#   'LightlyActiveMinutes': 248,
#   'SedentaryMinutes': 738,
#   'Calories': 1883},
#  {'Id': 1503960366,
#   'ActivityDate': '4/10/2016',
#   'TotalSteps': 10057,
#   'TotalDistance': 6.98000001907349,
#   'TrackerDistance': 6.98000001907349,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 4.0,
#   'ModeratelyActiveDistance': 0.490000009536743,
#   'LightActiveDistance': 2.4800000190734903,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 44,
#   'FairlyActiveMinutes': 13,
#   'LightlyActiveMinutes': 168,
#   'SedentaryMinutes': 737,
#   'Calories': 1755},
#  {'Id': 1503960366,
#   'ActivityDate': '4/11/2016',
#   'TotalSteps': 10990,
#   'TotalDistance': 7.2600002288818395,
#   'TrackerDistance': 7.2600002288818395,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 2.03999996185303,
#   'ModeratelyActiveDistance': 0.569999992847443,
#   'LightActiveDistance': 4.65000009536743,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 26,
#   'FairlyActiveMinutes': 14,
#   'LightlyActiveMinutes': 216,
#   'SedentaryMinutes': 855,
#   'Calories': 1811},
#  {'Id': 1503960366,
#   'ActivityDate': '4/12/2016',
#   'TotalSteps': 224,
#   'TotalDistance': 0.14000000059604598,
#   'TrackerDistance': 0.14000000059604598,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.129999995231628,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 9,
#   'SedentaryMinutes': 32,
#   'Calories': 50},
#  {'Id': 1624580081,
#   'ActivityDate': '3/25/2016',
#   'TotalSteps': 1810,
#   'TotalDistance': 1.17999994754791,
#   'TrackerDistance': 1.17999994754791,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.12999999523163,
#   'SedentaryActiveDistance': 0.00999999977648258,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 121,
#   'SedentaryMinutes': 1319,
#   'Calories': 1373},
#  {'Id': 1624580081,
#   'ActivityDate': '3/26/2016',
#   'TotalSteps': 815,
#   'TotalDistance': 0.5299999713897711,
#   'TrackerDistance': 0.5299999713897711,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.5299999713897711,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 47,
#   'SedentaryMinutes': 1393,
#   'Calories': 1264},
#  {'Id': 1624580081,
#   'ActivityDate': '3/27/2016',
#   'TotalSteps': 1985,
#   'TotalDistance': 1.28999996185303,
#   'TrackerDistance': 1.28999996185303,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.27999997138977,
#   'SedentaryActiveDistance': 0.00999999977648258,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 112,
#   'SedentaryMinutes': 1328,
#   'Calories': 1350},
#  {'Id': 1624580081,
#   'ActivityDate': '3/28/2016',
#   'TotalSteps': 1905,
#   'TotalDistance': 1.24000000953674,
#   'TrackerDistance': 1.24000000953674,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.24000000953674,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 95,
#   'SedentaryMinutes': 1345,
#   'Calories': 1342},
#  {'Id': 1624580081,
#   'ActivityDate': '3/29/2016',
#   'TotalSteps': 1552,
#   'TotalDistance': 1.00999999046326,
#   'TrackerDistance': 1.00999999046326,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.0,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 66,
#   'SedentaryMinutes': 1374,
#   'Calories': 1300},
#  {'Id': 1624580081,
#   'ActivityDate': '3/30/2016',
#   'TotalSteps': 1675,
#   'TotalDistance': 1.0900000333786,
#   'TrackerDistance': 1.0900000333786,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.0900000333786,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 84,
#   'SedentaryMinutes': 1356,
#   'Calories': 1313},
#  {'Id': 1624580081,
#   'ActivityDate': '3/31/2016',
#   'TotalSteps': 4506,
#   'TotalDistance': 2.9300000667572004,
#   'TrackerDistance': 2.9300000667572004,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.509999990463257,
#   'ModeratelyActiveDistance': 0.270000010728836,
#   'LightActiveDistance': 2.15000009536743,
#   'SedentaryActiveDistance': 0.00999999977648258,
#   'VeryActiveMinutes': 7,
#   'FairlyActiveMinutes': 4,
#   'LightlyActiveMinutes': 144,
#   'SedentaryMinutes': 1285,
#   'Calories': 1498},
#  {'Id': 1624580081,
#   'ActivityDate': '4/1/2016',
#   'TotalSteps': 9218,
#   'TotalDistance': 5.9899997711181605,
#   'TrackerDistance': 5.9899997711181605,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 5.96999979019165,
#   'SedentaryActiveDistance': 0.00999999977648258,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 221,
#   'SedentaryMinutes': 1219,
#   'Calories': 1541},
#  {'Id': 1624580081,
#   'ActivityDate': '4/2/2016',
#   'TotalSteps': 1556,
#   'TotalDistance': 1.00999999046326,
#   'TrackerDistance': 1.00999999046326,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.00999999046326,
#   'SedentaryActiveDistance': 0.00999999977648258,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 88,
#   'SedentaryMinutes': 1352,
#   'Calories': 1327},
#  {'Id': 1624580081,
#   'ActivityDate': '4/3/2016',
#   'TotalSteps': 2910,
#   'TotalDistance': 1.88999998569489,
#   'TrackerDistance': 1.88999998569489,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.87999999523163,
#   'SedentaryActiveDistance': 0.00999999977648258,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 157,
#   'SedentaryMinutes': 1283,
#   'Calories': 1452},
#  {'Id': 1624580081,
#   'ActivityDate': '4/4/2016',
#   'TotalSteps': 18464,
#   'TotalDistance': 12.0,
#   'TrackerDistance': 12.0,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 12.0,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 270,
#   'SedentaryMinutes': 1170,
#   'Calories': 1574},
#  {'Id': 1624580081,
#   'ActivityDate': '4/5/2016',
#   'TotalSteps': 1335,
#   'TotalDistance': 0.870000004768372,
#   'TrackerDistance': 0.870000004768372,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.870000004768372,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 74,
#   'SedentaryMinutes': 1366,
#   'Calories': 1308},
#  {'Id': 1624580081,
#   'ActivityDate': '4/6/2016',
#   'TotalSteps': 1004,
#   'TotalDistance': 0.6499999761581421,
#   'TrackerDistance': 0.6499999761581421,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.6499999761581421,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 55,
#   'SedentaryMinutes': 1385,
#   'Calories': 1276},
#  {'Id': 1624580081,
#   'ActivityDate': '4/7/2016',
#   'TotalSteps': 1111,
#   'TotalDistance': 0.720000028610229,
#   'TrackerDistance': 0.720000028610229,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.720000028610229,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 54,
#   'SedentaryMinutes': 1386,
#   'Calories': 1278},
#  {'Id': 1624580081,
#   'ActivityDate': '4/8/2016',
#   'TotalSteps': 6344,
#   'TotalDistance': 4.11999988555908,
#   'TrackerDistance': 4.11999988555908,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 4.099999904632569,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 143,
#   'SedentaryMinutes': 1297,
#   'Calories': 1409},
#  {'Id': 1624580081,
#   'ActivityDate': '4/9/2016',
#   'TotalSteps': 3572,
#   'TotalDistance': 2.3199999332428,
#   'TrackerDistance': 2.3199999332428,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 2.2899999618530296,
#   'SedentaryActiveDistance': 0.0299999993294477,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 122,
#   'SedentaryMinutes': 1318,
#   'Calories': 1370},
#  {'Id': 1624580081,
#   'ActivityDate': '4/10/2016',
#   'TotalSteps': 3910,
#   'TotalDistance': 2.5399999618530296,
#   'TrackerDistance': 2.5399999618530296,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.46999999880790705,
#   'ModeratelyActiveDistance': 0.25,
#   'LightActiveDistance': 1.8099999427795401,
#   'SedentaryActiveDistance': 0.00999999977648258,
#   'VeryActiveMinutes': 7,
#   'FairlyActiveMinutes': 7,
#   'LightlyActiveMinutes': 186,
#   'SedentaryMinutes': 1240,
#   'Calories': 1555},
#  {'Id': 1624580081,
#   'ActivityDate': '4/11/2016',
#   'TotalSteps': 10000,
#   'TotalDistance': 6.5,
#   'TrackerDistance': 6.5,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 6.5,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 172,
#   'SedentaryMinutes': 1268,
#   'Calories': 1469},
#  {'Id': 1624580081,
#   'ActivityDate': '4/12/2016',
#   'TotalSteps': 6627,
#   'TotalDistance': 4.30999994277954,
#   'TrackerDistance': 4.30999994277954,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 4.30999994277954,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 89,
#   'SedentaryMinutes': 604,
#   'Calories': 706},
#  {'Id': 1644430081,
#   'ActivityDate': '4/1/2016',
#   'TotalSteps': 4636,
#   'TotalDistance': 3.41000008583069,
#   'TrackerDistance': 3.41000008583069,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.779999971389771,
#   'LightActiveDistance': 2.5999999046325697,
#   'SedentaryActiveDistance': 0.0299999993294477,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 16,
#   'LightlyActiveMinutes': 586,
#   'SedentaryMinutes': 838,
#   'Calories': 3323},
#  {'Id': 1644430081,
#   'ActivityDate': '4/2/2016',
#   'TotalSteps': 20237,
#   'TotalDistance': 14.710000038147,
#   'TrackerDistance': 14.710000038147,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 2.5699999332428,
#   'ModeratelyActiveDistance': 6.400000095367429,
#   'LightActiveDistance': 5.73000001907349,
#   'SedentaryActiveDistance': 0.00999999977648258,
#   'VeryActiveMinutes': 34,
#   'FairlyActiveMinutes': 141,
#   'LightlyActiveMinutes': 347,
#   'SedentaryMinutes': 918,
#   'Calories': 4029},
#  {'Id': 1644430081,
#   'ActivityDate': '4/3/2016',
#   'TotalSteps': 12912,
#   'TotalDistance': 9.40999984741211,
#   'TrackerDistance': 9.40999984741211,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 4.82999992370605,
#   'ModeratelyActiveDistance': 0.769999980926514,
#   'LightActiveDistance': 3.7899999618530296,
#   'SedentaryActiveDistance': 0.0299999993294477,
#   'VeryActiveMinutes': 59,
#   'FairlyActiveMinutes': 16,
#   'LightlyActiveMinutes': 283,
#   'SedentaryMinutes': 1082,
#   'Calories': 3436},
#  {'Id': 1644430081,
#   'ActivityDate': '4/4/2016',
#   'TotalSteps': 2819,
#   'TotalDistance': 2.04999995231628,
#   'TrackerDistance': 2.04999995231628,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.31000000238418607,
#   'ModeratelyActiveDistance': 0.170000001788139,
#   'LightActiveDistance': 1.5599999427795401,
#   'SedentaryActiveDistance': 0.00999999977648258,
#   'VeryActiveMinutes': 4,
#   'FairlyActiveMinutes': 4,
#   'LightlyActiveMinutes': 87,
#   'SedentaryMinutes': 1345,
#   'Calories': 2444},
#  {'Id': 1644430081,
#   'ActivityDate': '4/5/2016',
#   'TotalSteps': 9921,
#   'TotalDistance': 7.21000003814697,
#   'TrackerDistance': 7.21000003814697,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.34000000357627896,
#   'ModeratelyActiveDistance': 1.5199999809265101,
#   'LightActiveDistance': 5.3600001335144,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 5,
#   'FairlyActiveMinutes': 35,
#   'LightlyActiveMinutes': 219,
#   'SedentaryMinutes': 1181,
#   'Calories': 3098},
#  {'Id': 1644430081,
#   'ActivityDate': '4/6/2016',
#   'TotalSteps': 8046,
#   'TotalDistance': 5.849999904632571,
#   'TrackerDistance': 5.849999904632571,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 1.28999996185303,
#   'ModeratelyActiveDistance': 2.11999988555908,
#   'LightActiveDistance': 2.4500000476837203,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 18,
#   'FairlyActiveMinutes': 41,
#   'LightlyActiveMinutes': 137,
#   'SedentaryMinutes': 1244,
#   'Calories': 2925},
#  {'Id': 1644430081,
#   'ActivityDate': '4/7/2016',
#   'TotalSteps': 11166,
#   'TotalDistance': 8.11999988555908,
#   'TrackerDistance': 8.11999988555908,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.209999993443489,
#   'ModeratelyActiveDistance': 2.41000008583069,
#   'LightActiveDistance': 5.5,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 3,
#   'FairlyActiveMinutes': 58,
#   'LightlyActiveMinutes': 230,
#   'SedentaryMinutes': 1149,
#   'Calories': 3202},
#  {'Id': 1644430081,
#   'ActivityDate': '4/8/2016',
#   'TotalSteps': 7842,
#   'TotalDistance': 5.699999809265139,
#   'TrackerDistance': 5.699999809265139,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.479999989271164,
#   'ModeratelyActiveDistance': 2.41000008583069,
#   'LightActiveDistance': 2.8099999427795397,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 7,
#   'FairlyActiveMinutes': 43,
#   'LightlyActiveMinutes': 161,
#   'SedentaryMinutes': 1229,
#   'Calories': 2928},
#  {'Id': 1644430081,
#   'ActivityDate': '4/9/2016',
#   'TotalSteps': 13840,
#   'TotalDistance': 10.0600004196167,
#   'TrackerDistance': 10.0600004196167,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 1.30999994277954,
#   'ModeratelyActiveDistance': 3.72000002861023,
#   'LightActiveDistance': 5.03000020980835,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 18,
#   'FairlyActiveMinutes': 81,
#   'LightlyActiveMinutes': 192,
#   'SedentaryMinutes': 1149,
#   'Calories': 3290},
#  {'Id': 1644430081,
#   'ActivityDate': '4/10/2016',
#   'TotalSteps': 1329,
#   'TotalDistance': 0.970000028610229,
#   'TrackerDistance': 0.970000028610229,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.970000028610229,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 35,
#   'SedentaryMinutes': 207,
#   'Calories': 489},
#  {'Id': 1844505072,
#   'ActivityDate': '4/1/2016',
#   'TotalSteps': 6847,
#   'TotalDistance': 4.53000020980835,
#   'TrackerDistance': 4.53000020980835,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.610000014305115,
#   'ModeratelyActiveDistance': 0.370000004768372,
#   'LightActiveDistance': 3.54999995231628,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 9,
#   'FairlyActiveMinutes': 9,
#   'LightlyActiveMinutes': 251,
#   'SedentaryMinutes': 1171,
#   'Calories': 1969},
#  {'Id': 1844505072,
#   'ActivityDate': '4/2/2016',
#   'TotalSteps': 5367,
#   'TotalDistance': 3.54999995231628,
#   'TrackerDistance': 3.54999995231628,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 3.54999995231628,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 263,
#   'SedentaryMinutes': 1177,
#   'Calories': 1889},
#  {'Id': 1844505072,
#   'ActivityDate': '4/3/2016',
#   'TotalSteps': 2841,
#   'TotalDistance': 1.87999999523163,
#   'TrackerDistance': 1.87999999523163,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.87999999523163,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 136,
#   'SedentaryMinutes': 1114,
#   'Calories': 1636},
#  {'Id': 1844505072,
#   'ActivityDate': '4/4/2016',
#   'TotalSteps': 0,
#   'TotalDistance': 0.0,
#   'TrackerDistance': 0.0,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.0,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 0,
#   'SedentaryMinutes': 669,
#   'Calories': 1347},
#  {'Id': 1844505072,
#   'ActivityDate': '4/5/2016',
#   'TotalSteps': 0,
#   'TotalDistance': 0.0,
#   'TrackerDistance': 0.0,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.0,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 0,
#   'SedentaryMinutes': 1440,
#   'Calories': 1347},
#  {'Id': 1844505072,
#   'ActivityDate': '4/6/2016',
#   'TotalSteps': 7,
#   'TotalDistance': 0.0,
#   'TrackerDistance': 0.0,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.0,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 1,
#   'SedentaryMinutes': 1439,
#   'Calories': 1349},
#  {'Id': 1844505072,
#   'ActivityDate': '4/7/2016',
#   'TotalSteps': 6344,
#   'TotalDistance': 4.19000005722046,
#   'TrackerDistance': 4.19000005722046,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 4.19000005722046,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 290,
#   'SedentaryMinutes': 1150,
#   'Calories': 1965},
#  {'Id': 1844505072,
#   'ActivityDate': '4/8/2016',
#   'TotalSteps': 5316,
#   'TotalDistance': 3.50999999046326,
#   'TrackerDistance': 3.50999999046326,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 3.50999999046326,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 221,
#   'SedentaryMinutes': 1219,
#   'Calories': 1824},
#  {'Id': 1844505072,
#   'ActivityDate': '4/9/2016',
#   'TotalSteps': 4979,
#   'TotalDistance': 3.2899999618530296,
#   'TrackerDistance': 3.2899999618530296,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 3.2899999618530296,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 184,
#   'SedentaryMinutes': 620,
#   'Calories': 1807},
#  {'Id': 1844505072,
#   'ActivityDate': '4/10/2016',
#   'TotalSteps': 6556,
#   'TotalDistance': 4.34000015258789,
#   'TrackerDistance': 4.34000015258789,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 4.32999992370605,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 305,
#   'SedentaryMinutes': 810,
#   'Calories': 1971},
#  {'Id': 1844505072,
#   'ActivityDate': '4/11/2016',
#   'TotalSteps': 5430,
#   'TotalDistance': 3.58999991416931,
#   'TrackerDistance': 3.58999991416931,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 3.58999991416931,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 251,
#   'SedentaryMinutes': 1189,
#   'Calories': 1888},
#  {'Id': 1844505072,
#   'ActivityDate': '4/12/2016',
#   'TotalSteps': 0,
#   'TotalDistance': 0.0,
#   'TrackerDistance': 0.0,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.0,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 0,
#   'SedentaryMinutes': 426,
#   'Calories': 399},
#  {'Id': 1927972279,
#   'ActivityDate': '4/1/2016',
#   'TotalSteps': 4317,
#   'TotalDistance': 2.99000000953674,
#   'TrackerDistance': 2.99000000953674,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.370000004768372,
#   'LightActiveDistance': 2.61999988555908,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 11,
#   'LightlyActiveMinutes': 192,
#   'SedentaryMinutes': 854,
#   'Calories': 2590},
#  {'Id': 1927972279,
#   'ActivityDate': '4/2/2016',
#   'TotalSteps': 5662,
#   'TotalDistance': 3.92000007629395,
#   'TrackerDistance': 3.92000007629395,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 3.92000007629395,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 267,
#   'SedentaryMinutes': 858,
#   'Calories': 2783},
#  {'Id': 1927972279,
#   'ActivityDate': '4/3/2016',
#   'TotalSteps': 3198,
#   'TotalDistance': 2.2100000381469704,
#   'TrackerDistance': 2.2100000381469704,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 2.2100000381469704,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 146,
#   'SedentaryMinutes': 1183,
#   'Calories': 2449},
#  {'Id': 1927972279,
#   'ActivityDate': '4/4/2016',
#   'TotalSteps': 2352,
#   'TotalDistance': 1.62999999523163,
#   'TrackerDistance': 1.62999999523163,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.62999999523163,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 128,
#   'SedentaryMinutes': 829,
#   'Calories': 2380},
#  {'Id': 1927972279,
#   'ActivityDate': '4/5/2016',
#   'TotalSteps': 2234,
#   'TotalDistance': 1.54999995231628,
#   'TrackerDistance': 1.54999995231628,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.54999995231628,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 108,
#   'SedentaryMinutes': 912,
#   'Calories': 2344},
#  {'Id': 1927972279,
#   'ActivityDate': '4/6/2016',
#   'TotalSteps': 1259,
#   'TotalDistance': 0.870000004768372,
#   'TrackerDistance': 0.870000004768372,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.870000004768372,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 73,
#   'SedentaryMinutes': 938,
#   'Calories': 2202},
#  {'Id': 1927972279,
#   'ActivityDate': '4/7/2016',
#   'TotalSteps': 768,
#   'TotalDistance': 0.5299999713897711,
#   'TrackerDistance': 0.5299999713897711,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.5299999713897711,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 43,
#   'SedentaryMinutes': 1397,
#   'Calories': 2130},
#  {'Id': 1927972279,
#   'ActivityDate': '4/8/2016',
#   'TotalSteps': 519,
#   'TotalDistance': 0.36000001430511497,
#   'TrackerDistance': 0.36000001430511497,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.36000001430511497,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 34,
#   'SedentaryMinutes': 1406,
#   'Calories': 2088},
#  {'Id': 1927972279,
#   'ActivityDate': '4/9/2016',
#   'TotalSteps': 2523,
#   'TotalDistance': 1.75,
#   'TrackerDistance': 1.75,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.370000004768372,
#   'LightActiveDistance': 1.37999999523163,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 9,
#   'LightlyActiveMinutes': 134,
#   'SedentaryMinutes': 1250,
#   'Calories': 2443},
#  {'Id': 1927972279,
#   'ActivityDate': '4/10/2016',
#   'TotalSteps': 2105,
#   'TotalDistance': 1.46000003814697,
#   'TrackerDistance': 1.46000003814697,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.46000003814697,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 139,
#   'SedentaryMinutes': 805,
#   'Calories': 2442},
#  {'Id': 1927972279,
#   'ActivityDate': '4/11/2016',
#   'TotalSteps': 1209,
#   'TotalDistance': 0.839999973773956,
#   'TrackerDistance': 0.839999973773956,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.839999973773956,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 73,
#   'SedentaryMinutes': 842,
#   'Calories': 2255},
#  {'Id': 1927972279,
#   'ActivityDate': '4/12/2016',
#   'TotalSteps': 24,
#   'TotalDistance': 0.0199999995529652,
#   'TrackerDistance': 0.0199999995529652,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.0199999995529652,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 3,
#   'SedentaryMinutes': 161,
#   'Calories': 942},
#  {'Id': 2022484408,
#   'ActivityDate': '4/1/2016',
#   'TotalSteps': 13603,
#   'TotalDistance': 9.60000038146973,
#   'TrackerDistance': 9.60000038146973,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 5.46000003814697,
#   'ModeratelyActiveDistance': 0.6299999952316279,
#   'LightActiveDistance': 3.50999999046326,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 72,
#   'FairlyActiveMinutes': 16,
#   'LightlyActiveMinutes': 213,
#   'SedentaryMinutes': 1139,
#   'Calories': 2645},
#  {'Id': 2022484408,
#   'ActivityDate': '4/2/2016',
#   'TotalSteps': 5477,
#   'TotalDistance': 3.83999991416931,
#   'TrackerDistance': 3.83999991416931,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 3.83999991416931,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 237,
#   'SedentaryMinutes': 1203,
#   'Calories': 2040},
#  {'Id': 2022484408,
#   'ActivityDate': '4/3/2016',
#   'TotalSteps': 11144,
#   'TotalDistance': 7.82000017166138,
#   'TrackerDistance': 7.82000017166138,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 1.78999996185303,
#   'ModeratelyActiveDistance': 0.8899999856948849,
#   'LightActiveDistance': 5.1399998664856,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 25,
#   'FairlyActiveMinutes': 22,
#   'LightlyActiveMinutes': 279,
#   'SedentaryMinutes': 1114,
#   'Calories': 2395},
#  {'Id': 2022484408,
#   'ActivityDate': '4/4/2016',
#   'TotalSteps': 15313,
#   'TotalDistance': 11.0,
#   'TrackerDistance': 11.0,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 5.019999980926509,
#   'ModeratelyActiveDistance': 1.28999996185303,
#   'LightActiveDistance': 4.69000005722046,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 62,
#   'FairlyActiveMinutes': 19,
#   'LightlyActiveMinutes': 233,
#   'SedentaryMinutes': 1126,
#   'Calories': 2581},
#  {'Id': 2022484408,
#   'ActivityDate': '4/5/2016',
#   'TotalSteps': 10805,
#   'TotalDistance': 7.59000015258789,
#   'TrackerDistance': 7.59000015258789,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.720000028610229,
#   'ModeratelyActiveDistance': 0.980000019073486,
#   'LightActiveDistance': 5.889999866485599,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 36,
#   'FairlyActiveMinutes': 37,
#   'LightlyActiveMinutes': 298,
#   'SedentaryMinutes': 1069,
#   'Calories': 2735},
#  {'Id': 2022484408,
#   'ActivityDate': '4/6/2016',
#   'TotalSteps': 15392,
#   'TotalDistance': 10.9300003051758,
#   'TrackerDistance': 10.9300003051758,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 3.4300000667572004,
#   'ModeratelyActiveDistance': 1.75,
#   'LightActiveDistance': 5.75,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 47,
#   'FairlyActiveMinutes': 42,
#   'LightlyActiveMinutes': 258,
#   'SedentaryMinutes': 1093,
#   'Calories': 2733},
#  {'Id': 2022484408,
#   'ActivityDate': '4/7/2016',
#   'TotalSteps': 18247,
#   'TotalDistance': 13.8299999237061,
#   'TrackerDistance': 13.8299999237061,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 7.110000133514401,
#   'ModeratelyActiveDistance': 2.2100000381469704,
#   'LightActiveDistance': 4.51000022888184,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 72,
#   'FairlyActiveMinutes': 62,
#   'LightlyActiveMinutes': 252,
#   'SedentaryMinutes': 1054,
#   'Calories': 3021},
#  {'Id': 2022484408,
#   'ActivityDate': '4/8/2016',
#   'TotalSteps': 13023,
#   'TotalDistance': 9.26000022888184,
#   'TrackerDistance': 9.26000022888184,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 3.2300000190734903,
#   'ModeratelyActiveDistance': 0.560000002384186,
#   'LightActiveDistance': 5.46999979019165,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 40,
#   'FairlyActiveMinutes': 12,
#   'LightlyActiveMinutes': 296,
#   'SedentaryMinutes': 1092,
#   'Calories': 2577},
#  {'Id': 2022484408,
#   'ActivityDate': '4/9/2016',
#   'TotalSteps': 16267,
#   'TotalDistance': 12.5900001525879,
#   'TrackerDistance': 12.5900001525879,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 5.75,
#   'ModeratelyActiveDistance': 0.46999999880790705,
#   'LightActiveDistance': 6.369999885559079,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 44,
#   'FairlyActiveMinutes': 16,
#   'LightlyActiveMinutes': 302,
#   'SedentaryMinutes': 1078,
#   'Calories': 2811},
#  {'Id': 2022484408,
#   'ActivityDate': '4/10/2016',
#   'TotalSteps': 10005,
#   'TotalDistance': 7.01999998092651,
#   'TrackerDistance': 7.01999998092651,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0799999982118607,
#   'ModeratelyActiveDistance': 1.04999995231628,
#   'LightActiveDistance': 5.900000095367429,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 1,
#   'FairlyActiveMinutes': 23,
#   'LightlyActiveMinutes': 339,
#   'SedentaryMinutes': 1077,
#   'Calories': 2458},
#  {'Id': 2022484408,
#   'ActivityDate': '4/11/2016',
#   'TotalSteps': 10106,
#   'TotalDistance': 7.09000015258789,
#   'TrackerDistance': 7.09000015258789,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 1.21000003814697,
#   'ModeratelyActiveDistance': 0.560000002384186,
#   'LightActiveDistance': 5.32999992370605,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 41,
#   'FairlyActiveMinutes': 16,
#   'LightlyActiveMinutes': 272,
#   'SedentaryMinutes': 1111,
#   'Calories': 2568},
#  {'Id': 2022484408,
#   'ActivityDate': '4/12/2016',
#   'TotalSteps': 6717,
#   'TotalDistance': 4.71999979019165,
#   'TrackerDistance': 4.71999979019165,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 3.2300000190734903,
#   'ModeratelyActiveDistance': 0.219999998807907,
#   'LightActiveDistance': 1.26999998092651,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 41,
#   'FairlyActiveMinutes': 5,
#   'LightlyActiveMinutes': 67,
#   'SedentaryMinutes': 551,
#   'Calories': 1140},
#  {'Id': 2026352035,
#   'ActivityDate': '4/1/2016',
#   'TotalSteps': 2605,
#   'TotalDistance': 1.62000000476837,
#   'TrackerDistance': 1.62000000476837,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.62000000476837,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 166,
#   'SedentaryMinutes': 729,
#   'Calories': 1407},
#  {'Id': 2026352035,
#   'ActivityDate': '4/2/2016',
#   'TotalSteps': 1229,
#   'TotalDistance': 0.7599999904632572,
#   'TrackerDistance': 0.7599999904632572,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.7599999904632572,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 69,
#   'SedentaryMinutes': 795,
#   'Calories': 1237},
#  {'Id': 2026352035,
#   'ActivityDate': '4/3/2016',
#   'TotalSteps': 2308,
#   'TotalDistance': 1.42999994754791,
#   'TrackerDistance': 1.42999994754791,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.42999994754791,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 115,
#   'SedentaryMinutes': 720,
#   'Calories': 1330},
#  {'Id': 2026352035,
#   'ActivityDate': '4/4/2016',
#   'TotalSteps': 6679,
#   'TotalDistance': 4.1399998664856,
#   'TrackerDistance': 4.1399998664856,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 4.1399998664856,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 263,
#   'SedentaryMinutes': 644,
#   'Calories': 1583},
#  {'Id': 2026352035,
#   'ActivityDate': '4/5/2016',
#   'TotalSteps': 5645,
#   'TotalDistance': 3.5,
#   'TrackerDistance': 3.5,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 3.5,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 248,
#   'SedentaryMinutes': 621,
#   'Calories': 1538},
#  {'Id': 2026352035,
#   'ActivityDate': '4/6/2016',
#   'TotalSteps': 3180,
#   'TotalDistance': 1.9700000286102302,
#   'TrackerDistance': 1.9700000286102302,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.9700000286102302,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 185,
#   'SedentaryMinutes': 738,
#   'Calories': 1421},
#  {'Id': 2026352035,
#   'ActivityDate': '4/7/2016',
#   'TotalSteps': 2767,
#   'TotalDistance': 1.7200000286102302,
#   'TrackerDistance': 1.7200000286102302,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.7200000286102302,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 170,
#   'SedentaryMinutes': 673,
#   'Calories': 1392},
#  {'Id': 2026352035,
#   'ActivityDate': '4/8/2016',
#   'TotalSteps': 3762,
#   'TotalDistance': 2.32999992370605,
#   'TrackerDistance': 2.32999992370605,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 2.32999992370605,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 173,
#   'SedentaryMinutes': 719,
#   'Calories': 1425},
#  {'Id': 2026352035,
#   'ActivityDate': '4/9/2016',
#   'TotalSteps': 3098,
#   'TotalDistance': 1.91999995708466,
#   'TrackerDistance': 1.91999995708466,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.91999995708466,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 185,
#   'SedentaryMinutes': 700,
#   'Calories': 1413},
#  {'Id': 2026352035,
#   'ActivityDate': '4/10/2016',
#   'TotalSteps': 5142,
#   'TotalDistance': 3.1900000572204603,
#   'TrackerDistance': 3.1900000572204603,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 3.1900000572204603,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 230,
#   'SedentaryMinutes': 654,
#   'Calories': 1515},
#  {'Id': 2026352035,
#   'ActivityDate': '4/11/2016',
#   'TotalSteps': 3279,
#   'TotalDistance': 2.02999997138977,
#   'TrackerDistance': 2.02999997138977,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 2.02999997138977,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 164,
#   'SedentaryMinutes': 694,
#   'Calories': 1405},
#  {'Id': 2026352035,
#   'ActivityDate': '4/12/2016',
#   'TotalSteps': 1019,
#   'TotalDistance': 0.6299999952316279,
#   'TrackerDistance': 0.6299999952316279,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.6299999952316279,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 64,
#   'SedentaryMinutes': 223,
#   'Calories': 600},
#  {'Id': 2320127002,
#   'ActivityDate': '4/1/2016',
#   'TotalSteps': 0,
#   'TotalDistance': 0.0,
#   'TrackerDistance': 0.0,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.0,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 0,
#   'SedentaryMinutes': 1440,
#   'Calories': 1324},
#  {'Id': 2320127002,
#   'ActivityDate': '4/2/2016',
#   'TotalSteps': 0,
#   'TotalDistance': 0.0,
#   'TrackerDistance': 0.0,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.0,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 0,
#   'SedentaryMinutes': 1440,
#   'Calories': 1324},
#  {'Id': 2320127002,
#   'ActivityDate': '4/3/2016',
#   'TotalSteps': 0,
#   'TotalDistance': 0.0,
#   'TrackerDistance': 0.0,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.0,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 0,
#   'SedentaryMinutes': 1440,
#   'Calories': 1324},
#  {'Id': 2320127002,
#   'ActivityDate': '4/4/2016',
#   'TotalSteps': 0,
#   'TotalDistance': 0.0,
#   'TrackerDistance': 0.0,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.0,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 0,
#   'SedentaryMinutes': 1440,
#   'Calories': 1324},
#  {'Id': 2320127002,
#   'ActivityDate': '4/5/2016',
#   'TotalSteps': 4931,
#   'TotalDistance': 3.3199999332427996,
#   'TrackerDistance': 3.3199999332427996,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 3.3199999332427996,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 175,
#   'SedentaryMinutes': 1265,
#   'Calories': 1708},
#  {'Id': 2320127002,
#   'ActivityDate': '4/6/2016',
#   'TotalSteps': 6999,
#   'TotalDistance': 4.71999979019165,
#   'TrackerDistance': 4.71999979019165,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 4.71999979019165,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 320,
#   'SedentaryMinutes': 1120,
#   'Calories': 1950},
#  {'Id': 2320127002,
#   'ActivityDate': '4/7/2016',
#   'TotalSteps': 1846,
#   'TotalDistance': 1.24000000953674,
#   'TrackerDistance': 1.24000000953674,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.24000000953674,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
# ...
#   'LightActiveDistance': 4.59000015258789,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 74,
#   'FairlyActiveMinutes': 17,
#   'LightlyActiveMinutes': 182,
#   'SedentaryMinutes': 811,
#   'Calories': 3775},
#  {'Id': 8378563200,
#   'ActivityDate': '4/12/2016',
#   'TotalSteps': 3246,
#   'TotalDistance': 2.5699999332428,
#   'TrackerDistance': 2.5699999332428,
#   'LoggedActivitiesDistance': 2.25308108329773,
#   'VeryActiveDistance': 0.8299999833106991,
#   'ModeratelyActiveDistance': 0.709999978542328,
#   'LightActiveDistance': 1.02999997138977,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 65,
#   'FairlyActiveMinutes': 15,
#   'LightlyActiveMinutes': 49,
#   'SedentaryMinutes': 243,
#   'Calories': 1882},
#  {'Id': 8583815059,
#   'ActivityDate': '4/1/2016',
#   'TotalSteps': 2174,
#   'TotalDistance': 1.70000004768372,
#   'TrackerDistance': 1.70000004768372,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.70000004768372,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 112,
#   'SedentaryMinutes': 1328,
#   'Calories': 2360},
#  {'Id': 8583815059,
#   'ActivityDate': '4/2/2016',
#   'TotalSteps': 3494,
#   'TotalDistance': 2.7300000190734903,
#   'TrackerDistance': 2.7300000190734903,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 2.6900000572204603,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 166,
#   'SedentaryMinutes': 1274,
#   'Calories': 2517},
#  {'Id': 8583815059,
#   'ActivityDate': '4/3/2016',
#   'TotalSteps': 2380,
#   'TotalDistance': 1.86000001430511,
#   'TrackerDistance': 1.86000001430511,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.86000001430511,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 131,
#   'SedentaryMinutes': 1309,
#   'Calories': 2400},
#  {'Id': 8583815059,
#   'ActivityDate': '4/4/2016',
#   'TotalSteps': 3159,
#   'TotalDistance': 2.4600000381469704,
#   'TrackerDistance': 2.4600000381469704,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 2.4600000381469704,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 147,
#   'SedentaryMinutes': 1293,
#   'Calories': 2462},
#  {'Id': 8583815059,
#   'ActivityDate': '4/5/2016',
#   'TotalSteps': 6835,
#   'TotalDistance': 5.32999992370605,
#   'TrackerDistance': 5.32999992370605,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.370000004768372,
#   'ModeratelyActiveDistance': 0.730000019073486,
#   'LightActiveDistance': 4.23999977111816,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 5,
#   'FairlyActiveMinutes': 15,
#   'LightlyActiveMinutes': 212,
#   'SedentaryMinutes': 1208,
#   'Calories': 2786},
#  {'Id': 8583815059,
#   'ActivityDate': '4/6/2016',
#   'TotalSteps': 2098,
#   'TotalDistance': 1.63999998569489,
#   'TrackerDistance': 1.63999998569489,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.62999999523163,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 112,
#   'SedentaryMinutes': 1328,
#   'Calories': 2354},
#  {'Id': 8583815059,
#   'ActivityDate': '4/7/2016',
#   'TotalSteps': 2816,
#   'TotalDistance': 2.2000000476837203,
#   'TrackerDistance': 2.2000000476837203,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 2.2000000476837203,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 138,
#   'SedentaryMinutes': 1302,
#   'Calories': 2437},
#  {'Id': 8583815059,
#   'ActivityDate': '4/8/2016',
#   'TotalSteps': 1408,
#   'TotalDistance': 1.1000000238418601,
#   'TrackerDistance': 1.1000000238418601,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.1000000238418601,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 79,
#   'SedentaryMinutes': 1052,
#   'Calories': 1814},
#  {'Id': 8792009665,
#   'ActivityDate': '4/1/2016',
#   'TotalSteps': 4592,
#   'TotalDistance': 2.9400000572204603,
#   'TrackerDistance': 2.9400000572204603,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.100000001490116,
#   'ModeratelyActiveDistance': 0.14000000059604598,
#   'LightActiveDistance': 2.70000004768372,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 4,
#   'FairlyActiveMinutes': 8,
#   'LightlyActiveMinutes': 176,
#   'SedentaryMinutes': 748,
#   'Calories': 2260},
#  {'Id': 8792009665,
#   'ActivityDate': '4/2/2016',
#   'TotalSteps': 8452,
#   'TotalDistance': 5.40999984741211,
#   'TrackerDistance': 5.40999984741211,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.259999990463257,
#   'ModeratelyActiveDistance': 0.38999998569488503,
#   'LightActiveDistance': 4.76000022888184,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 9,
#   'FairlyActiveMinutes': 24,
#   'LightlyActiveMinutes': 328,
#   'SedentaryMinutes': 1079,
#   'Calories': 3004},
#  {'Id': 8792009665,
#   'ActivityDate': '4/3/2016',
#   'TotalSteps': 7238,
#   'TotalDistance': 4.63000011444092,
#   'TrackerDistance': 4.63000011444092,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.10999999940395402,
#   'ModeratelyActiveDistance': 0.23000000417232502,
#   'LightActiveDistance': 4.28999996185303,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 2,
#   'FairlyActiveMinutes': 6,
#   'LightlyActiveMinutes': 279,
#   'SedentaryMinutes': 636,
#   'Calories': 2667},
#  {'Id': 8792009665,
#   'ActivityDate': '4/4/2016',
#   'TotalSteps': 3821,
#   'TotalDistance': 2.4500000476837203,
#   'TrackerDistance': 2.4500000476837203,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.219999998807907,
#   'LightActiveDistance': 2.2300000190734903,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 9,
#   'LightlyActiveMinutes': 161,
#   'SedentaryMinutes': 675,
#   'Calories': 2229},
#  {'Id': 8792009665,
#   'ActivityDate': '4/5/2016',
#   'TotalSteps': 2332,
#   'TotalDistance': 1.4900000095367398,
#   'TrackerDistance': 1.4900000095367398,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.00999999977648258,
#   'ModeratelyActiveDistance': 0.180000007152557,
#   'LightActiveDistance': 1.29999995231628,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 1,
#   'FairlyActiveMinutes': 10,
#   'LightlyActiveMinutes': 111,
#   'SedentaryMinutes': 904,
#   'Calories': 2100},
#  {'Id': 8792009665,
#   'ActivityDate': '4/6/2016',
#   'TotalSteps': 2121,
#   'TotalDistance': 1.36000001430511,
#   'TrackerDistance': 1.36000001430511,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.36000001430511,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 122,
#   'SedentaryMinutes': 855,
#   'Calories': 2114},
#  {'Id': 8792009665,
#   'ActivityDate': '4/7/2016',
#   'TotalSteps': 1291,
#   'TotalDistance': 0.8299999833106991,
#   'TrackerDistance': 0.8299999833106991,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.8299999833106991,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 77,
#   'SedentaryMinutes': 888,
#   'Calories': 1961},
#  {'Id': 8792009665,
#   'ActivityDate': '4/8/2016',
#   'TotalSteps': 1467,
#   'TotalDistance': 0.9399999976158141,
#   'TrackerDistance': 0.9399999976158141,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.100000001490116,
#   'ModeratelyActiveDistance': 0.209999993443489,
#   'LightActiveDistance': 0.6299999952316279,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 2,
#   'FairlyActiveMinutes': 8,
#   'LightlyActiveMinutes': 71,
#   'SedentaryMinutes': 912,
#   'Calories': 1953},
#  {'Id': 8792009665,
#   'ActivityDate': '4/9/2016',
#   'TotalSteps': 1022,
#   'TotalDistance': 0.6499999761581421,
#   'TrackerDistance': 0.6499999761581421,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.6499999761581421,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 63,
#   'SedentaryMinutes': 739,
#   'Calories': 1890},
#  {'Id': 8792009665,
#   'ActivityDate': '4/10/2016',
#   'TotalSteps': 4605,
#   'TotalDistance': 2.95000004768372,
#   'TrackerDistance': 2.95000004768372,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 2.95000004768372,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 179,
#   'SedentaryMinutes': 1261,
#   'Calories': 2253},
#  {'Id': 8792009665,
#   'ActivityDate': '4/11/2016',
#   'TotalSteps': 178,
#   'TotalDistance': 0.10999999940395402,
#   'TrackerDistance': 0.10999999940395402,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.10999999940395402,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 12,
#   'SedentaryMinutes': 1428,
#   'Calories': 1725},
#  {'Id': 8792009665,
#   'ActivityDate': '4/12/2016',
#   'TotalSteps': 20,
#   'TotalDistance': 0.00999999977648258,
#   'TrackerDistance': 0.00999999977648258,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.00999999977648258,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 6,
#   'SedentaryMinutes': 598,
#   'Calories': 728},
#  {'Id': 8877689391,
#   'ActivityDate': '4/1/2016',
#   'TotalSteps': 18700,
#   'TotalDistance': 15.8199996948242,
#   'TrackerDistance': 15.8199996948242,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 8.699999809265138,
#   'ModeratelyActiveDistance': 0.159999996423721,
#   'LightActiveDistance': 6.90999984741211,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 67,
#   'FairlyActiveMinutes': 3,
#   'LightlyActiveMinutes': 247,
#   'SedentaryMinutes': 1123,
#   'Calories': 3527},
#  {'Id': 8877689391,
#   'ActivityDate': '4/2/2016',
#   'TotalSteps': 27572,
#   'TotalDistance': 23.3899993896484,
#   'TrackerDistance': 23.3899993896484,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 14.720000267028801,
#   'ModeratelyActiveDistance': 1.21000003814697,
#   'LightActiveDistance': 7.34000015258789,
#   'SedentaryActiveDistance': 0.00999999977648258,
#   'VeryActiveMinutes': 116,
#   'FairlyActiveMinutes': 24,
#   'LightlyActiveMinutes': 260,
#   'SedentaryMinutes': 1040,
#   'Calories': 4220},
#  {'Id': 8877689391,
#   'ActivityDate': '4/3/2016',
#   'TotalSteps': 15260,
#   'TotalDistance': 8.189999580383299,
#   'TrackerDistance': 8.189999580383299,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 1.79999995231628,
#   'ModeratelyActiveDistance': 0.75,
#   'LightActiveDistance': 5.57000017166138,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 106,
#   'FairlyActiveMinutes': 17,
#   'LightlyActiveMinutes': 259,
#   'SedentaryMinutes': 1058,
#   'Calories': 3864},
#  {'Id': 8877689391,
#   'ActivityDate': '4/4/2016',
#   'TotalSteps': 20779,
#   'TotalDistance': 18.409999847412102,
#   'TrackerDistance': 18.409999847412102,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 11.729999542236301,
#   'ModeratelyActiveDistance': 0.6499999761581421,
#   'LightActiveDistance': 6.0,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 78,
#   'FairlyActiveMinutes': 16,
#   'LightlyActiveMinutes': 208,
#   'SedentaryMinutes': 1138,
#   'Calories': 3662},
#  {'Id': 8877689391,
#   'ActivityDate': '4/5/2016',
#   'TotalSteps': 10695,
#   'TotalDistance': 8.11999988555908,
#   'TrackerDistance': 8.11999988555908,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.769999980926514,
#   'ModeratelyActiveDistance': 0.180000007152557,
#   'LightActiveDistance': 7.09000015258789,
#   'SedentaryActiveDistance': 0.00999999977648258,
#   'VeryActiveMinutes': 10,
#   'FairlyActiveMinutes': 3,
#   'LightlyActiveMinutes': 246,
#   'SedentaryMinutes': 1181,
#   'Calories': 2834},
#  {'Id': 8877689391,
#   'ActivityDate': '4/6/2016',
#   'TotalSteps': 24136,
#   'TotalDistance': 20.909999847412102,
#   'TrackerDistance': 20.909999847412102,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 12.220000267028801,
#   'ModeratelyActiveDistance': 0.540000021457672,
#   'LightActiveDistance': 8.07999992370605,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 87,
#   'FairlyActiveMinutes': 16,
#   'LightlyActiveMinutes': 318,
#   'SedentaryMinutes': 1019,
#   'Calories': 4039},
#  {'Id': 8877689391,
#   'ActivityDate': '4/7/2016',
#   'TotalSteps': 10910,
#   'TotalDistance': 8.42000007629395,
#   'TrackerDistance': 8.42000007629395,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 2.9600000381469704,
#   'ModeratelyActiveDistance': 0.38999998569488503,
#   'LightActiveDistance': 5.03000020980835,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 32,
#   'FairlyActiveMinutes': 11,
#   'LightlyActiveMinutes': 212,
#   'SedentaryMinutes': 1185,
#   'Calories': 2947},
#  {'Id': 8877689391,
#   'ActivityDate': '4/8/2016',
#   'TotalSteps': 23014,
#   'TotalDistance': 20.3899993896484,
#   'TrackerDistance': 20.3899993896484,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 11.1000003814697,
#   'ModeratelyActiveDistance': 0.6299999952316279,
#   'LightActiveDistance': 8.61999988555908,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 70,
#   'FairlyActiveMinutes': 29,
#   'LightlyActiveMinutes': 359,
#   'SedentaryMinutes': 982,
#   'Calories': 4196},
#  {'Id': 8877689391,
#   'ActivityDate': '4/9/2016',
#   'TotalSteps': 16470,
#   'TotalDistance': 8.06999969482422,
#   'TrackerDistance': 8.06999969482422,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0199999995529652,
#   'LightActiveDistance': 8.02000045776367,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 90,
#   'FairlyActiveMinutes': 9,
#   'LightlyActiveMinutes': 289,
#   'SedentaryMinutes': 1052,
#   'Calories': 3841},
#  {'Id': 8877689391,
#   'ActivityDate': '4/10/2016',
#   'TotalSteps': 28497,
#   'TotalDistance': 27.530000686645497,
#   'TrackerDistance': 27.530000686645497,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 21.9200000762939,
#   'ModeratelyActiveDistance': 1.12000000476837,
#   'LightActiveDistance': 4.46000003814697,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 128,
#   'FairlyActiveMinutes': 46,
#   'LightlyActiveMinutes': 211,
#   'SedentaryMinutes': 1055,
#   'Calories': 4526},
#  {'Id': 8877689391,
#   'ActivityDate': '4/11/2016',
#   'TotalSteps': 10622,
#   'TotalDistance': 8.060000419616701,
#   'TrackerDistance': 8.060000419616701,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 1.4700000286102302,
#   'ModeratelyActiveDistance': 0.150000005960464,
#   'LightActiveDistance': 6.369999885559079,
#   'SedentaryActiveDistance': 0.00999999977648258,
#   'VeryActiveMinutes': 18,
#   'FairlyActiveMinutes': 7,
#   'LightlyActiveMinutes': 225,
#   'SedentaryMinutes': 1190,
#   'Calories': 2820},
#  {'Id': 8877689391,
#   'ActivityDate': '4/12/2016',
#   'TotalSteps': 2350,
#   'TotalDistance': 1.7799999713897698,
#   'TrackerDistance': 1.7799999713897698,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.7799999713897698,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 58,
#   'SedentaryMinutes': 531,
#   'Calories': 938}]

# %%
db = client["FitBitdata"]

# %%
print(db)
# Out:
# Database(MongoClient(host=['ac-qkiby54-shard-00-00.jfsm9ty.mongodb.net:27017', 'ac-qkiby54-shard-00-02.jfsm9ty.mongodb.net:27017', 'ac-qkiby54-shard-00-01.jfsm9ty.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-xd67ar-shard-0', tls=True), 'FitBitdata')

# %%
db.FitBit.insert_many(data)

# %%
#3. Convert all the dates avaible in dataset to timestamp format in pandas and in sql you to convert it in date format
fitbit = pd.read_csv(r"C:\Users\Downloads\FitBitdata.csv")
fitbit
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
# [457 rows x 15 columns]

# %%
fitbit.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
fitbit['ActivityDate']= pd.to_datetime(fitbit['ActivityDate'])

# %%
fitbit.dtypes
# Out:
# Id                                   int64
# ActivityDate                datetime64[ns]
# TotalSteps                           int64
# TotalDistance                      float64
# TrackerDistance                    float64
# LoggedActivitiesDistance           float64
# VeryActiveDistance                 float64
# ModeratelyActiveDistance           float64
# LightActiveDistance                float64
# SedentaryActiveDistance            float64
# VeryActiveMinutes                    int64
# FairlyActiveMinutes                  int64
# LightlyActiveMinutes                 int64
# SedentaryMinutes                     int64
# Calories                             int64
# dtype: object

# %%
#4. Find out in this data that how many unique id's we have 
len(fitbit['Id'].unique()) #There are 35 unique id's
# Out:
# 35

# %%
#5. which id is one of the active id that you have in whole dataset 
fitbit["TotalActiveMinutes"]=(fitbit['VeryActiveMinutes']+fitbit['FairlyActiveMinutes'] + fitbit['LightlyActiveMinutes'])

# %%
fitbit.sort_values('TotalActiveMinutes', ascending=False).max() #Id 8877689391 is the most active id in the entire dataset
# Out:
# Id                                   8877689391
# ActivityDate                2016-04-12 00:00:00
# TotalSteps                                28497
# TotalDistance                             27.53
# TrackerDistance                           27.53
# LoggedActivitiesDistance                6.72706
# VeryActiveDistance                        21.92
# ModeratelyActiveDistance                    6.4
# LightActiveDistance                       12.51
# SedentaryActiveDistance                     0.1
# VeryActiveMinutes                           202
# FairlyActiveMinutes                         660
# LightlyActiveMinutes                        720
# SedentaryMinutes                           1440
# Calories                                   4562
# TotalActiveMinutes                          720
# dtype: object

# %%
fitbit.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories',
#        'TotalActiveMinutes'],
#       dtype='object')

# %%
#6. how many of them have not logged there activity find out in terms of number of ids 
len(fitbit[fitbit['TotalActiveMinutes']== 0]) #There are total 68 id's that have not logged their activity
# Out:
# 68

# %%
#7. Find out who is the laziest person id that we have in dataset 
fitbit[fitbit['Calories']>0].sort_values(['Calories']).reset_index().iloc[[0]] #Person with ID 1503960366 is the laziest person
# Out:
#    index          Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0     18  1503960366   2016-04-12         224           0.14             0.14
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                 0.0                       0.0
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 0.13                      0.0                  0
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                    0                     9                32        50
#
#    TotalActiveMinutes
# 0                   9

# %%
#8. Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset 
#According to Internet: As a general guideline, women typically burn about 2,000 calories per day and men burn about 2,500 calories per day. These numbers are often used to determine 
#an approximate food intake for weight maintenance. As we don.t know the exact gender of the person, we will take average of both.
#i.e. 2250 calories are required to be burned per day for a healthy person.
len(fitbit[fitbit['Calories']>2250]['Id'].unique()) #So there are 24 persons who are healthy
# Out:
# 24

# %%
#And if we consider the minimum calories of the required calories burnt, then :
len(fitbit[fitbit['Calories']>2000]['Id'].unique())
# Out:
# 30

# %%
#9. how many person are not a regular person with respect to activity try to find out those 
fitbit
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-03-25       11004       7.110000         7.110000
# 1    1503960366   2016-03-26       17609      11.550000        11.550000
# 2    1503960366   2016-03-27       12736       8.530000         8.530000
# 3    1503960366   2016-03-28       13231       8.930000         8.930000
# 4    1503960366   2016-03-29       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   2016-04-08       23014      20.389999        20.389999
# 453  8877689391   2016-04-09       16470       8.070000         8.070000
# 454  8877689391   2016-04-10       28497      27.530001        27.530001
# 455  8877689391   2016-04-11       10622       8.060000         8.060000
# 456  8877689391   2016-04-12        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#      TotalActiveMinutes
# 0                   250
# 1                   380
# 2                   329
# 3                   283
# 4                   299
# ..                  ...
# 452                 458
# 453                 388
# 454                 385
# 455                 250
# 456                  58
#
# [457 rows x 16 columns]

# %%
#10. who is the third most active person in this dataset find out those in pandas and in sql both . 
res.sort_values("TotalActiveMinutes", ascending = False).reset_index().iloc[[2]]
# Out:
#    index          Id  TotalSteps  TotalDistance  TrackerDistance  \
# 2     26  6962181067      176956         121.07       117.400001
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 2                 14.052416               36.13                     24.99
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 2                59.85                      0.1                495
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 2                  406                  3620              8488     29249
#
#    TotalActiveMinutes
# 2                4521

# %%
#11. who is the 5th most laziest person avilable in dataset find it out 
res.sort_values('TotalSteps').reset_index().iloc[[4]]
# Out:
#    index          Id  TotalSteps  TotalDistance  TrackerDistance  \
# 4     32  8583815059       24364          19.02            19.02
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 4                       0.0                0.37                      0.73
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 4                17.88                      0.0                  5
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 4                   15                  1097             10094     19130
#
#    TotalActiveMinutes
# 4                1117

# %%
#12. what is a total Cumulative Calories burn for a person find out 
res = fitbit.groupby('Id',as_index = False).sum()

# %%
res[[ "Id", 'Calories']]
# Out:
#             Id  Calories
# 0   1503960366     34128
# 1   1624580081     25705
# 2   1644430081     29164
# 3   1844505072     19391
# 4   1927972279     27048
# 5   2022484408     29704
# 6   2026352035     16266
# 7   2320127002     18385
# 8   2347167796     30320
# 9   2873212765     20349
# 10  2891001357     18187
# 11  3372868164     18603
# 12  3977333714     16777
# 13  4020332650     98412
# 14  4057192912     60913
# 15  4319703577     23931
# 16  4388161847     14442
# 17  4445114986     31617
# 18  4558609924     21962
# 19  4702921684     42322
# 20  5553957443     21630
# 21  5577150313     36303
# 22  6117666160     20993
# 23  6290855005     21656
# 24  6391747486     15868
# 25  6775888955     24523
# 26  6962181067     29249
# 27  7007744171     31525
# 28  7086361926     26124
# 29  8053475328     31825
# 30  8253242879     17556
# 31  8378563200     40274
# 32  8583815059     19130
# 33  8792009665     24884
# 34  8877689391     41414

# %% [markdown]
# **TASK 2 SOLUTIONS**

# %%
#1. Load this data in sql and in pandas with a relation in sql 
#2. While loading this data you dont have to create a table manually you can use any automated approach to create a table and load a data in bulk in table 
import pandas as pd
import xlrd
import csv
import mysql.connector as conn

# %%
mydb = conn.connect(host = 'localhost', user = 'root', passwd = 'useyourpwd')
cursor = mydb.cursor(buffered=True)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+pymysql://root:8067@localhost/superstore')

# %%
orders = pd.read_excel("SuperStore_USA.xlsx",skipinitialspace = True,names =["RowID","OrderPriority","Discount","UnitPrice","ShippingCost","CustomerID","CustomerName","ShipMode","CustomerSegment","ProductCategory","ProductSub-Category","ProductContainer","ProductName","ProductBase Margin","Region","StateorProvince","City","PostalCode","OrderDate","ShipDate","Profit","Quantityorderednew","Sales","OrderID"])

# %%
orders.to_sql('orders', con=engine)

# %%
type(orders)
# Out:
# pandas.core.frame.DataFrame

# %%
cursor = mydb.cursor()

cursor.execute("SELECT * FROM superstore.orders")

myresult = cursor.fetchall()

for x in myresult:
  print(x)
# Out:
# (0, 18606, 'Not Specified', 0.01, 2.88, 0.5, 2, 'Janice Fletcher', 'Regular Air', 'Corporate', 'Office Supplies', 'Labels', 'Small Box', 'Avery 49', 0.36, 'Central', 'Illinois', 'Addison', 60101, datetime.datetime(2012, 5, 28, 0, 0), datetime.datetime(2012, 5, 30, 0, 0), 1.32, 2, 5.9, 88525)
# (1, 20847, 'High', 0.01, 2.84, 0.93, 3, 'Bonnie Potter', 'Express Air', 'Corporate', 'Office Supplies', 'Pens & Art Supplies', 'Wrap Bag', 'SANFORD Liquid Accent™ Tank-Style Highlighters', 0.54, 'West', 'Washington', 'Anacortes', 98221, datetime.datetime(2010, 7, 7, 0, 0), datetime.datetime(2010, 7, 8, 0, 0), 4.56, 4, 13.01, 88522)
# (2, 23086, 'Not Specified', 0.03, 6.68, 6.15, 3, 'Bonnie Potter', 'Express Air', 'Corporate', 'Office Supplies', 'Paper', 'Small Box', 'Xerox 1968', 0.37, 'West', 'Washington', 'Anacortes', 98221, datetime.datetime(2011, 7, 27, 0, 0), datetime.datetime(2011, 7, 28, 0, 0), -47.64, 7, 49.92, 88523)
# (3, 23087, 'Not Specified', 0.01, 5.68, 3.6, 3, 'Bonnie Potter', 'Regular Air', 'Corporate', 'Office Supplies', 'Scissors, Rulers and Trimmers', 'Small Pack', 'Acme® Preferred Stainless Steel Scissors', 0.56, 'West', 'Washington', 'Anacortes', 98221, datetime.datetime(2011, 7, 27, 0, 0), datetime.datetime(2011, 7, 28, 0, 0), -30.51, 7, 41.64, 88523)
# (4, 23088, 'Not Specified', 0.0, 205.99, 2.5, 3, 'Bonnie Potter', 'Express Air', 'Corporate', 'Technology', 'Telephones and Communication', 'Small Box', 'V70', 0.59, 'West', 'Washington', 'Anacortes', 98221, datetime.datetime(2011, 7, 27, 0, 0), datetime.datetime(2011, 7, 27, 0, 0), 998.2022999999999, 8, 1446.67, 88523)
# (5, 23597, 'Medium', 0.09, 55.48, 14.3, 3, 'Bonnie Potter', 'Express Air', 'Corporate', 'Office Supplies', 'Paper', 'Small Box', 'Xerox 194', 0.37, 'West', 'Washington', 'Anacortes', 98221, datetime.datetime(2011, 11, 9, 0, 0), datetime.datetime(2011, 11, 11, 0, 0), 1388.0522999999998, 37, 2011.67, 88524)
# (6, 25549, 'Low', 0.08, 120.97, 26.3, 3, 'Bonnie Potter', 'Delivery Truck', 'Corporate', 'Technology', 'Office Machines', 'Jumbo Drum', 'Canon S750 Color Inkjet Printer', 0.38, 'West', 'Washington', 'Anacortes', 98221, datetime.datetime(2013, 7, 1, 0, 0), datetime.datetime(2013, 7, 8, 0, 0), 1001.4452999999999, 12, 1451.37, 88526)
# (7, 20228, 'Not Specified', 0.02, 500.98, 26.0, 5, 'Ronnie Proctor', 'Delivery Truck', 'Home Office', 'Furniture', 'Chairs & Chairmats', 'Jumbo Drum', 'Global Troy™ Executive Leather Low-Back Tilter', 0.6, 'West', 'California', 'San Gabriel', 91776, datetime.datetime(2010, 12, 13, 0, 0), datetime.datetime(2010, 12, 15, 0, 0), 4390.3665, 12, 6362.85, 90193)
# (8, 19483, 'Low', 0.08, 6.48, 6.81, 5, 'Ronnie Proctor', 'Regular Air', 'Home Office', 'Office Supplies', 'Paper', 'Small Box', 'Xerox 1930', 0.36, 'West', 'California', 'San Gabriel', 91776, datetime.datetime(2012, 5, 12, 0, 0), datetime.datetime(2012, 5, 21, 0, 0), -141.26, 18, 113.25, 90197)
# (9, 24782, 'High', 0.01, 90.24, 0.99, 6, 'Dwight Hwang', 'Regular Air', 'Home Office', 'Office Supplies', 'Appliances', 'Small Box', 'Kensington 6 Outlet MasterPiece® HOMEOFFICE Power Control Center', 0.56, 'West', 'California', 'San Jose', 95123, datetime.datetime(2011, 5, 26, 0, 0), datetime.datetime(2011, 5, 26, 0, 0), 1045.4673, 16, 1515.17, 90194)
# (10, 24563, 'Critical', 0.07, 6.48, 6.6, 6, 'Dwight Hwang', 'Regular Air', 'Home Office', 'Office Supplies', 'Paper', 'Small Box', 'Xerox 21', 0.37, 'West', 'California', 'San Jose', 95123, datetime.datetime(2012, 12, 29, 0, 0), datetime.datetime(2012, 12, 31, 0, 0), -13.86, 4, 28.61, 90200)
# (11, 24564, 'Critical', 0.01, 4.84, 0.71, 6, 'Dwight Hwang', 'Regular Air', 'Home Office', 'Office Supplies', 'Pens & Art Supplies', 'Wrap Bag', '*Staples* Highlighting Markers', 0.52, 'West', 'California', 'San Jose', 95123, datetime.datetime(2012, 12, 29, 0, 0), datetime.datetime(2012, 12, 31, 0, 0), 57.5805, 17, 83.45, 90200)
# (12, 24565, 'Critical', 0.1, 85.99, 0.99, 6, 'Dwight Hwang', 'Regular Air', 'Home Office', 'Technology', 'Telephones and Communication', 'Wrap Bag', 'Accessory34', 0.55, 'West', 'California', 'San Jose', 95123, datetime.datetime(2012, 12, 29, 0, 0), datetime.datetime(2012, 12, 31, 0, 0), 1176.5051999999998, 24, 1705.08, 90200)
# (13, 21866, 'High', 0.05, 12.28, 4.86, 7, 'Leon Gill', 'Regular Air', 'Home Office', 'Office Supplies', 'Paper', 'Small Box', 'Xerox 1933', 0.38, 'East', 'Massachusetts', 'Fall River', 2724, datetime.datetime(2012, 10, 30, 0, 0), datetime.datetime(2012, 10, 31, 0, 0), 72.9928, 19, 232.95, 90198)
# (14, 20876, 'Medium', 0.08, 140.98, 36.09, 8, 'Melanie Garner', 'Delivery Truck', 'Home Office', 'Furniture', 'Bookcases', 'Jumbo Box', 'Sauder Forest Hills Library, Woodland Oak Finish', 0.77, 'East', 'New Hampshire', 'Bedford', 3110, datetime.datetime(2012, 12, 25, 0, 0), datetime.datetime(2012, 12, 26, 0, 0), -158.74, 5, 705.47, 90199)
# (15, 20877, 'Medium', 0.1, 286.85, 61.76, 9, 'Lorraine Houston', 'Delivery Truck', 'Home Office', 'Furniture', 'Tables', 'Jumbo Box', 'Riverside Furniture Stanwyck Manor Table Series', 0.78, 'East', 'New Jersey', 'Camden', 8101, datetime.datetime(2012, 12, 25, 0, 0), datetime.datetime(2012, 12, 27, 0, 0), -346.6151975000001, 8, 1794.27, 90199)
# (16, 22241, 'Critical', 0.06, 15.57, 1.39, 10, 'Meredith Norris Thomas', 'Regular Air', 'Home Office', 'Office Supplies', 'Envelopes', 'Small Box', 'Park Ridge™ Embossed Executive Business Envelopes', 0.38, 'East', 'New Jersey', 'Pennsauken', 8109, datetime.datetime(2011, 10, 4, 0, 0), datetime.datetime(2011, 10, 5, 0, 0), 142.79549999999998, 14, 206.95, 90195)
# (17, 21776, 'Critical', 0.06, 9.48, 7.29, 11, 'Marcus Dunlap', 'Regular Air', 'Home Office', 'Furniture', 'Office Furnishings', 'Small Pack', 'DAX Two-Tone Rosewood/Black Document Frame, Desktop, 5 x 7', 0.45, 'East', 'New Jersey', 'Roselle', 7203, datetime.datetime(2010, 8, 15, 0, 0), datetime.datetime(2010, 8, 17, 0, 0), -53.8096, 22, 211.15, 90192)
# (18, 23328, 'High', 0.04, 10.98, 3.37, 12, 'Kara Pace', 'Regular Air', 'Home Office', 'Office Supplies', 'Scissors, Rulers and Trimmers', 'Small Pack', 'Fiskars® Softgrip Scissors', 0.57, 'East', 'Rhode Island', 'Cranston', 2907, datetime.datetime(2012, 2, 24, 0, 0), datetime.datetime(2012, 2, 26, 0, 0), 23.12, 8, 90.39, 90196)
# (19, 24844, 'Medium', 0.09, 78.69, 19.99, 14, 'Gwendolyn F Tyson', 'Regular Air', 'Small Business', 'Furniture', 'Office Furnishings', 'Small Box', 'Howard Miller 12-3/4 Diameter Accuwave DS ™ Wall Clock', 0.43, 'Central', 'Minnesota', 'Prior Lake', 55372, datetime.datetime(2010, 5, 12, 0, 0), datetime.datetime(2010, 5, 14, 0, 0), 803.4705, 16, 1164.45, 86838)
# (20, 24846, 'Medium', 0.08, 3.28, 2.31, 14, 'Gwendolyn F Tyson', 'Regular Air', 'Small Business', 'Office Supplies', 'Pens & Art Supplies', 'Wrap Bag', 'Newell 321', 0.56, 'Central', 'Minnesota', 'Prior Lake', 55372, datetime.datetime(2010, 5, 12, 0, 0), datetime.datetime(2010, 5, 13, 0, 0), -24.03, 7, 22.23, 86838)
# (21, 24847, 'Medium', 0.05, 3.28, 4.2, 14, 'Gwendolyn F Tyson', 'Regular Air', 'Small Business', 'Office Supplies', 'Pens & Art Supplies', 'Wrap Bag', 'Newell 351', 0.56, 'Central', 'Minnesota', 'Prior Lake', 55372, datetime.datetime(2010, 5, 12, 0, 0), datetime.datetime(2010, 5, 13, 0, 0), -37.03, 4, 13.99, 86838)
# (22, 24848, 'Medium', 0.05, 3.58, 1.63, 14, 'Gwendolyn F Tyson', 'Regular Air', 'Small Business', 'Office Supplies', 'Rubber Bands', 'Wrap Bag', 'OIC Colored Binder Clips, Assorted Sizes', 0.36, 'Central', 'Minnesota', 'Prior Lake', 55372, datetime.datetime(2010, 5, 12, 0, 0), datetime.datetime(2010, 5, 13, 0, 0), -0.71, 4, 14.26, 86838)
# (23, 24845, 'Medium', 0.01, 6.48, 7.86, 14, 'Gwendolyn F Tyson', 'Regular Air', 'Small Business', 'Office Supplies', 'Paper', 'Small Box', 'Xerox 213', 0.37, 'Central', 'Minnesota', 'Prior Lake', 55372, datetime.datetime(2013, 5, 12, 0, 0), datetime.datetime(2013, 5, 13, 0, 0), -44.54, 4, 29.55, 86845)
# (24, 18181, 'Critical', 0.0, 4.42, 4.99, 15, 'Timothy Reese', 'Regular Air', 'Small Business', 'Office Supplies', 'Envelopes', 'Small Box', 'Grip Seal Envelopes', 0.38, 'East', 'New York', 'Smithtown', 11787, datetime.datetime(2010, 4, 8, 0, 0), datetime.datetime(2010, 4, 9, 0, 0), -59.82, 7, 33.47, 86837)
# (25, 20925, 'Medium', 0.01, 35.94, 6.66, 15, 'Timothy Reese', 'Regular Air', 'Small Business', 'Office Supplies', 'Envelopes', 'Small Box', 'Tyvek ® Top-Opening Peel & Seel ® Envelopes, Gray', 0.4, 'East', 'New York', 'Smithtown', 11787, datetime.datetime(2010, 5, 28, 0, 0), datetime.datetime(2010, 5, 28, 0, 0), 261.87569999999994, 10, 379.53, 86839)
# (26, 18263, 'Medium', 0.03, 1.76, 0.7, 15, 'Timothy Reese', 'Regular Air', 'Small Business', 'Office Supplies', 'Pens & Art Supplies', 'Wrap Bag', 'Newell 310', 0.56, 'East', 'New York', 'Smithtown', 11787, datetime.datetime(2011, 12, 4, 0, 0), datetime.datetime(2011, 12, 6, 0, 0), -1.17, 10, 17.39, 86840)
# (27, 18554, 'Medium', 0.04, 5.98, 5.2, 15, 'Timothy Reese', 'Regular Air', 'Small Business', 'Office Supplies', 'Paper', 'Small Box', 'Xerox 1992', 0.36, 'East', 'New York', 'Smithtown', 11787, datetime.datetime(2012, 4, 29, 0, 0), datetime.datetime(2012, 5, 1, 0, 0), -24.03, 3, 19.04, 86841)
# (28, 22781, 'Low', 0.0, 7.59, 4.0, 15, 'Timothy Reese', 'Regular Air', 'Small Business', 'Furniture', 'Office Furnishings', 'Wrap Bag', 'Master Giant Foot® Doorstop, Safety Yellow', 0.42, 'East', 'New York', 'Smithtown', 11787, datetime.datetime(2013, 1, 19, 0, 0), datetime.datetime(2013, 1, 21, 0, 0), 23.266799999999996, 4, 33.72, 86842)
# (29, 23287, 'Low', 0.07, 4.13, 6.89, 15, 'Timothy Reese', 'Regular Air', 'Small Business', 'Office Supplies', 'Labels', 'Small Box', 'Avery 05222 Permanent Self-Adhesive File Folder Labels for Typewriters, on Rolls, White, 250/Roll', 0.39, 'East', 'New York', 'Smithtown', 11787, datetime.datetime(2013, 1, 21, 0, 0), datetime.datetime(2013, 1, 23, 0, 0), -174.2696, 9, 38.18, 86843)
# (30, 26267, 'High', 0.04, 2.98, 1.58, 16, 'Sarah Ramsey', 'Regular Air', 'Small Business', 'Office Supplies', 'Rubber Bands', 'Wrap Bag', 'Staples Gold Paper Clips', 0.39, 'East', 'New York', 'Syracuse', 13210, datetime.datetime(2010, 2, 12, 0, 0), datetime.datetime(2010, 2, 15, 0, 0), 2.63, 6, 18.8, 86836)
# (31, 26268, 'High', 0.05, 115.99, 2.5, 16, 'Sarah Ramsey', 'Regular Air', 'Small Business', 'Technology', 'Telephones and Communication', 'Small Box', 'StarTAC 7797', 0.55, 'East', 'New York', 'Syracuse', 13210, datetime.datetime(2010, 2, 12, 0, 0), datetime.datetime(2010, 2, 14, 0, 0), 652.7330999999999, 10, 945.99, 86836)
# (32, 26266, 'High', 0.08, 14.27, 7.27, 16, 'Sarah Ramsey', 'Express Air', 'Small Business', 'Office Supplies', 'Binders and Binder Accessories', 'Small Box', 'GBC Laser Imprintable Binding System Covers, Desert Sand', 0.38, 'East', 'New York', 'Syracuse', 13210, datetime.datetime(2013, 2, 12, 0, 0), datetime.datetime(2013, 2, 15, 0, 0), 3.4595000000000002, 3, 45.6, 86844)
# (33, 19359, 'Low', 0.05, 5.85, 2.27, 17, 'Florence Hsu Schwarz', 'Regular Air', 'Small Business', 'Office Supplies', 'Pens & Art Supplies', 'Wrap Bag', 'Dixon My First Ticonderoga Pencil, #2', 0.56, 'West', 'Montana', 'Great Falls', 59405, datetime.datetime(2011, 4, 20, 0, 0), datetime.datetime(2011, 4, 24, 0, 0), -6.82, 2, 12.18, 90033)
# (34, 20459, 'Critical', 0.05, 7.77, 9.23, 17, 'Florence Hsu Schwarz', 'Express Air', 'Small Business', 'Office Supplies', 'Appliances', 'Small Box', 'Hoover Commercial Soft Guard Upright Vacuum And Disposable Filtration Bags', 0.58, 'West', 'Montana', 'Great Falls', 59405, datetime.datetime(2012, 4, 6, 0, 0), datetime.datetime(2012, 4, 8, 0, 0), -96.33, 4, 34.75, 90034)
# (35, 23890, 'High', 0.05, 26.48, 6.93, 18, 'Laurie Hanna', 'Regular Air', 'Small Business', 'Furniture', 'Office Furnishings', 'Small Box', 'DAX Natural Wood-Tone Poster Frame', 0.49, 'West', 'Montana', 'Helena', 59601, datetime.datetime(2010, 5, 15, 0, 0), datetime.datetime(2010, 5, 16, 0, 0), 314.4813, 17, 455.77, 90031)
# (36, 21763, 'Critical', 0.08, 42.98, 4.62, 18, 'Laurie Hanna', 'Express Air', 'Small Business', 'Office Supplies', 'Appliances', 'Small Box', 'Belkin F9M820V08 8 Outlet Surge', 0.56, 'West', 'Montana', 'Helena', 59601, datetime.datetime(2012, 5, 15, 0, 0), datetime.datetime(2012, 5, 16, 0, 0), 446.07809999999995, 15, 646.49, 90035)
# (37, 21764, 'Critical', 0.07, 8.04, 8.94, 18, 'Laurie Hanna', 'Express Air', 'Small Business', 'Office Supplies', 'Binders and Binder Accessories', 'Small Box', 'Fellowes Twister Kit, Gray/Clear, 3/pkg', 0.4, 'West', 'Montana', 'Helena', 59601, datetime.datetime(2012, 5, 15, 0, 0), datetime.datetime(2012, 5, 15, 0, 0), -117.1045, 9, 75.85, 90035)
# (38, 24062, 'Not Specified', 0.08, 5.0, 3.39, 18, 'Laurie Hanna', 'Regular Air', 'Small Business', 'Office Supplies', 'Rubber Bands', 'Wrap Bag', 'Advantus Plastic Paper Clips', 0.37, 'West', 'Montana', 'Helena', 59601, datetime.datetime(2013, 5, 21, 0, 0), datetime.datetime(2013, 5, 22, 0, 0), -17.49, 13, 65.69, 90038)
# (39, 20578, 'Low', 0.02, 110.98, 30.0, 18, 'Laurie Hanna', 'Delivery Truck', 'Small Business', 'Furniture', 'Chairs & Chairmats', 'Jumbo Drum', 'Office Star Flex Back Scooter Chair with White Frame', 0.71, 'West', 'Montana', 'Helena', 59601, datetime.datetime(2013, 10, 2, 0, 0), datetime.datetime(2013, 10, 4, 0, 0), 126.31, 22, 2575.93, 90039)
# (40, 20579, 'Low', 0.01, 12.53, 0.5, 18, 'Laurie Hanna', 'Regular Air', 'Small Business', 'Office Supplies', 'Labels', 'Small Box', 'Avery 485', 0.38, 'West', 'Montana', 'Helena', 59601, datetime.datetime(2013, 10, 2, 0, 0), datetime.datetime(2013, 10, 4, 0, 0), 152.7867, 17, 221.43, 90039)
# (41, 24063, 'Not Specified', 0.07, 12.99, 9.44, 19, 'Jim Rodgers', 'Regular Air', 'Small Business', 'Technology', 'Office Machines', 'Medium Box', 'Hewlett Packard 6S Scientific Calculator', 0.39, 'West', 'Montana', 'Missoula', 59801, datetime.datetime(2010, 5, 21, 0, 0), datetime.datetime(2010, 5, 23, 0, 0), -114.63990000000001, 18, 231.79, 90032)
# (42, 25082, 'Not Specified', 0.06, 64.65, 35.0, 20, 'Marion Nolan Kaplan', 'Express Air', 'Small Business', 'Office Supplies', 'Storage & Organization', 'Large Box', 'Space Solutions Commercial Steel Shelving', 0.8, 'Central', 'Nebraska', 'Bellevue', 68005, datetime.datetime(2012, 5, 31, 0, 0), datetime.datetime(2012, 6, 2, 0, 0), -929.68, 13, 802.21, 90036)
# (43, 25083, 'Not Specified', 0.0, 15.23, 27.75, 20, 'Marion Nolan Kaplan', 'Delivery Truck', 'Small Business', 'Furniture', 'Tables', 'Jumbo Box', 'Anderson Hickey Conga Table Tops & Accessories', 0.76, 'Central', 'Nebraska', 'Bellevue', 68005, datetime.datetime(2012, 5, 31, 0, 0), datetime.datetime(2012, 6, 1, 0, 0), -53.784, 1, 24.48, 90036)
# (44, 25711, 'Medium', 0.0, 30.98, 17.08, 20, 'Marion Nolan Kaplan', 'Regular Air', 'Small Business', 'Office Supplies', 'Paper', 'Small Box', 'Xerox 197', 0.4, 'Central', 'Nebraska', 'Bellevue', 68005, datetime.datetime(2013, 3, 7, 0, 0), datetime.datetime(2013, 3, 8, 0, 0), -41.82, 1, 49.61, 90037)
# (45, 5890, 'High', 0.05, 26.48, 6.93, 21, 'Tony Wilkins Winters', 'Regular Air', 'Small Business', 'Furniture', 'Office Furnishings', 'Small Box', 'DAX Natural Wood-Tone Poster Frame', 0.49, 'East', 'New York', 'New York City', 10012, datetime.datetime(2010, 5, 15, 0, 0), datetime.datetime(2010, 5, 16, 0, 0), 384.38, 70, 1876.69, 41793)
# (46, 6062, 'Not Specified', 0.08, 5.0, 3.39, 21, 'Tony Wilkins Winters', 'Regular Air', 'Small Business', 'Office Supplies', 'Rubber Bands', 'Wrap Bag', 'Advantus Plastic Paper Clips', 0.37, 'East', 'New York', 'New York City', 10012, datetime.datetime(2010, 5, 21, 0, 0), datetime.datetime(2010, 5, 22, 0, 0), -17.49, 58, 293.06, 42949)
# (47, 6063, 'Not Specified', 0.07, 12.99, 9.44, 21, 'Tony Wilkins Winters', 'Regular Air', 'Small Business', 'Technology', 'Office Machines', 'Medium Box', 'Hewlett Packard 6S Scientific Calculator', 0.39, 'East', 'New York', 'New York City', 10012, datetime.datetime(2010, 5, 21, 0, 0), datetime.datetime(2010, 5, 23, 0, 0), -114.63990000000001, 71, 914.29, 42949)
# (48, 7711, 'Medium', 0.0, 30.98, 17.08, 21, 'Tony Wilkins Winters', 'Regular Air', 'Small Business', 'Office Supplies', 'Paper', 'Small Box', 'Xerox 197', 0.4, 'East', 'New York', 'New York City', 10012, datetime.datetime(2011, 3, 7, 0, 0), datetime.datetime(2011, 3, 8, 0, 0), -41.82, 1, 49.61, 55269)
# (49, 1359, 'Low', 0.05, 5.85, 2.27, 21, 'Tony Wilkins Winters', 'Regular Air', 'Small Business', 'Office Supplies', 'Pens & Art Supplies', 'Wrap Bag', 'Dixon My First Ticonderoga Pencil, #2', 0.56, 'East', 'New York', 'New York City', 10012, datetime.datetime(2011, 4, 20, 0, 0), datetime.datetime(2011, 4, 24, 0, 0), -6.82, 9, 54.79, 9895)
# (50, 2459, 'Critical', 0.05, 7.77, 9.23, 21, 'Tony Wilkins Winters', 'Express Air', 'Small Business', 'Office Supplies', 'Appliances', 'Small Box', 'Hoover Commercial Soft Guard Upright Vacuum And Disposable Filtration Bags', 0.58, 'East', 'New York', 'New York City', 10012, datetime.datetime(2012, 4, 6, 0, 0), datetime.datetime(2012, 4, 8, 0, 0), -96.33, 18, 156.38, 17860)
# (51, 3763, 'Critical', 0.08, 42.98, 4.62, 21, 'Tony Wilkins Winters', 'Express Air', 'Small Business', 'Office Supplies', 'Appliances', 'Small Box', 'Belkin F9M820V08 8 Outlet Surge', 0.56, 'East', 'New York', 'New York City', 10012, datetime.datetime(2012, 5, 15, 0, 0), datetime.datetime(2012, 5, 16, 0, 0), 461.65, 60, 2585.97, 26887)
# (52, 3764, 'Critical', 0.07, 8.04, 8.94, 21, 'Tony Wilkins Winters', 'Express Air', 'Small Business', 'Office Supplies', 'Binders and Binder Accessories', 'Small Box', 'Fellowes Twister Kit, Gray/Clear, 3/pkg', 0.4, 'East', 'New York', 'New York City', 10012, datetime.datetime(2012, 5, 15, 0, 0), datetime.datetime(2012, 5, 15, 0, 0), -117.1045, 36, 303.4, 26887)
# (53, 7082, 'Not Specified', 0.06, 64.65, 35.0, 21, 'Tony Wilkins Winters', 'Express Air', 'Small Business', 'Office Supplies', 'Storage & Organization', 'Large Box', 'Space Solutions Commercial Steel Shelving', 0.8, 'East', 'New York', 'New York City', 10012, datetime.datetime(2012, 5, 31, 0, 0), datetime.datetime(2012, 6, 2, 0, 0), -929.68, 50, 3085.41, 50533)
# (54, 7083, 'Not Specified', 0.0, 15.23, 27.75, 21, 'Tony Wilkins Winters', 'Delivery Truck', 'Small Business', 'Furniture', 'Tables', 'Jumbo Box', 'Anderson Hickey Conga Table Tops & Accessories', 0.76, 'East', 'New York', 'New York City', 10012, datetime.datetime(2012, 5, 31, 0, 0), datetime.datetime(2012, 6, 1, 0, 0), -53.784, 5, 122.4, 50533)
# (55, 2578, 'Low', 0.02, 110.98, 30.0, 21, 'Tony Wilkins Winters', 'Delivery Truck', 'Small Business', 'Furniture', 'Chairs & Chairmats', 'Jumbo Drum', 'Office Star Flex Back Scooter Chair with White Frame', 0.71, 'East', 'New York', 'New York City', 10012, datetime.datetime(2013, 10, 2, 0, 0), datetime.datetime(2013, 10, 4, 0, 0), 126.31, 88, 10303.73, 18596)
# (56, 2579, 'Low', 0.01, 12.53, 0.5, 21, 'Tony Wilkins Winters', 'Regular Air', 'Small Business', 'Office Supplies', 'Labels', 'Small Box', 'Avery 485', 0.38, 'East', 'New York', 'New York City', 10012, datetime.datetime(2013, 10, 2, 0, 0), datetime.datetime(2013, 10, 4, 0, 0), 223.38, 67, 872.68, 18596)
# (57, 19249, 'High', 0.05, 14.34, 5.0, 23, 'Lynn Moss', 'Regular Air', 'Corporate', 'Furniture', 'Office Furnishings', 'Small Pack', 'Nu-Dell Leatherette Frames', 0.49, 'West', 'California', 'Laguna Hills', 92653, datetime.datetime(2011, 11, 11, 0, 0), datetime.datetime(2011, 11, 12, 0, 0), 284.52600000000007, 36, 519.23, 87655)
# (58, 19250, 'High', 0.0, 30.98, 8.74, 23, 'Lynn Moss', 'Regular Air', 'Corporate', 'Office Supplies', 'Paper', 'Small Box', 'Xerox 1979', 0.4, 'West', 'California', 'Laguna Hills', 92653, datetime.datetime(2011, 11, 11, 0, 0), datetime.datetime(2011, 11, 12, 0, 0), 859.2638999999999, 37, 1245.31, 87655)
# (59, 18350, 'Not Specified', 0.07, 22.84, 5.47, 23, 'Lynn Moss', 'Express Air', 'Corporate', 'Office Supplies', 'Paper', 'Small Box', 'Xerox 1929', 0.39, 'West', 'California', 'Laguna Hills', 92653, datetime.datetime(2012, 9, 10, 0, 0), datetime.datetime(2012, 9, 13, 0, 0), 83.24, 7, 165.11, 87660)
# (60, 18478, 'Low', 0.1, 146.05, 80.2, 23, 'Lynn Moss', 'Delivery Truck', 'Corporate', 'Furniture', 'Tables', 'Jumbo Box', 'BPI Conference Tables', 0.71, 'West', 'California', 'Laguna Hills', 92653, datetime.datetime(2013, 11, 18, 0, 0), datetime.datetime(2013, 11, 25, 0, 0), 353.7721600000002, 11, 1591.71, 87669)
# (61, 20631, 'High', 0.06, 55.48, 14.3, 24, 'Edna Thomas', 'Regular Air', 'Corporate', 'Office Supplies', 'Paper', 'Small Box', 'Xerox 194', 0.37, 'West', 'California', 'Laguna Niguel', 92677, datetime.datetime(2010, 1, 28, 0, 0), datetime.datetime(2010, 1, 29, 0, 0), -28.2968, 1, 67.49, 87651)
# (62, 20632, 'High', 0.02, 1.68, 1.57, 24, 'Edna Thomas', 'Regular Air', 'Corporate', 'Office Supplies', 'Pens & Art Supplies', 'Wrap Bag', 'Newell 323', 0.59, 'West', 'California', 'Laguna Niguel', 92677, datetime.datetime(2010, 1, 28, 0, 0), datetime.datetime(2010, 1, 30, 0, 0), -5.3072, 1, 2.25, 87651)
# (63, 20309, 'Not Specified', 0.07, 205.99, 2.5, 24, 'Edna Thomas', 'Regular Air', 'Corporate', 'Technology', 'Telephones and Communication', 'Small Box', 'V70', 0.59, 'West', 'California', 'Laguna Niguel', 92677, datetime.datetime(2012, 3, 2, 0, 0), datetime.datetime(2012, 3, 4, 0, 0), 1489.8410999999999, 13, 2159.19, 87656)
# (64, 20625, 'High', 0.06, 21.38, 8.99, 24, 'Edna Thomas', 'Regular Air', 'Corporate', 'Office Supplies', 'Pens & Art Supplies', 'Small Pack', 'Boston 1730 StandUp Electric Pencil Sharpener', 0.59, 'West', 'California', 'Laguna Niguel', 92677, datetime.datetime(2012, 12, 19, 0, 0), datetime.datetime(2012, 12, 20, 0, 0), -23.415, 5, 105.99, 87662)
# (65, 21196, 'Critical', 0.07, 11.7, 6.96, 24, 'Edna Thomas', 'Regular Air', 'Corporate', 'Office Supplies', 'Appliances', 'Medium Box', 'Harmony HEPA Quiet Air Purifiers', 0.5, 'West', 'California', 'Laguna Niguel', 92677, datetime.datetime(2013, 1, 13, 0, 0), datetime.datetime(2013, 1, 14, 0, 0), -88.102, 8, 89.77, 87663)
# (66, 21253, 'High', 0.02, 5.98, 3.85, 25, 'Virginia Hardison', 'Regular Air', 'Corporate', 'Technology', 'Computer Peripherals', 'Small Pack', 'Imation 3.5" IBM-Formatted Diskettes, 10/Pack', 0.68, 'West', 'California', 'Lake Elsinore', 92530, datetime.datetime(2012, 4, 18, 0, 0), datetime.datetime(2012, 4, 20, 0, 0), -27.13, 1, 7.12, 87657)
# (67, 21254, 'High', 0.05, 5.98, 5.2, 25, 'Virginia Hardison', 'Regular Air', 'Corporate', 'Office Supplies', 'Paper', 'Small Box', 'Xerox 1992', 0.36, 'West', 'California', 'Lake Elsinore', 92530, datetime.datetime(2012, 4, 18, 0, 0), datetime.datetime(2012, 4, 20, 0, 0), -10.58, 1, 7.81, 87657)
# (68, 21251, 'Critical', 0.06, 25.98, 5.37, 25, 'Virginia Hardison', 'Regular Air', 'Corporate', 'Office Supplies', 'Appliances', 'Medium Box', '3M Office Air Cleaner', 0.5, 'West', 'California', 'Lake Elsinore', 92530, datetime.datetime(2013, 7, 2, 0, 0), datetime.datetime(2013, 7, 4, 0, 0), 86.51776, 7, 174.54, 87666)
# (69, 21252, 'Critical', 0.05, 155.06, 7.07, 25, 'Virginia Hardison', 'Regular Air', 'Corporate', 'Office Supplies', 'Storage & Organization', 'Small Box', 'Dual Level, Single-Width Filing Carts', 0.59, 'West', 'California', 'Lake Elsinore', 92530, datetime.datetime(2013, 7, 2, 0, 0), datetime.datetime(2013, 7, 4, 0, 0), 1268.4891, 12, 1838.39, 87666)
# (70, 22410, 'Medium', 0.08, 59.98, 3.99, 26, 'Marguerite Kane', 'Regular Air', 'Corporate', 'Office Supplies', 'Appliances', 'Small Box', 'Belkin 8 Outlet SurgeMaster II Gold Surge Protector', 0.57, 'West', 'California', 'Lake Forest', 92630, datetime.datetime(2012, 6, 27, 0, 0), datetime.datetime(2012, 6, 29, 0, 0), 420.984, 11, 619.14, 87658)
# (71, 22737, 'Not Specified', 0.0, 2.89, 0.5, 26, 'Marguerite Kane', 'Express Air', 'Corporate', 'Office Supplies', 'Labels', 'Small Box', 'Avery 498', 0.38, 'West', 'California', 'Lake Forest', 92630, datetime.datetime(2013, 9, 2, 0, 0), datetime.datetime(2013, 9, 3, 0, 0), 19.409699999999997, 7, 28.13, 87667)
# (72, 21292, 'High', 0.09, 3.69, 0.5, 26, 'Marguerite Kane', 'Regular Air', 'Corporate', 'Office Supplies', 'Labels', 'Small Box', 'Avery 52', 0.38, 'West', 'California', 'Lake Forest', 92630, datetime.datetime(2013, 12, 11, 0, 0), datetime.datetime(2013, 12, 12, 0, 0), 37.3704, 15, 54.16, 87670)
# (73, 21293, 'High', 0.06, 65.99, 8.99, 26, 'Marguerite Kane', 'Regular Air', 'Corporate', 'Technology', 'Telephones and Communication', 'Small Box', 'V 3600 Series', 0.58, 'West', 'California', 'Lake Forest', 92630, datetime.datetime(2013, 12, 11, 0, 0), datetime.datetime(2013, 12, 12, 0, 0), -85.606752, 3, 170.67, 87670)
# (74, 23967, 'Not Specified', 0.04, 4.14, 6.6, 27, 'Guy Gallagher', 'Regular Air', 'Corporate', 'Furniture', 'Office Furnishings', 'Small Box', 'Eldon Image Series Black Desk Accessories', 0.49, 'West', 'California', 'Lakewood', 90712, datetime.datetime(2010, 11, 2, 0, 0), datetime.datetime(2010, 11, 4, 0, 0), 8.894000000000005, 12, 54.78, 87652)
# (75, 23535, 'Low', 0.1, 35.44, 19.99, 27, 'Guy Gallagher', 'Regular Air', 'Corporate', 'Office Supplies', 'Paper', 'Small Box', 'Xerox 1880', 0.38, 'West', 'California', 'Lakewood', 90712, datetime.datetime(2012, 7, 12, 0, 0), datetime.datetime(2012, 7, 14, 0, 0), -47.01, 4, 142.51, 87659)
# (76, 23536, 'Low', 0.06, 55.48, 14.3, 27, 'Guy Gallagher', 'Regular Air', 'Corporate', 'Office Supplies', 'Paper', 'Small Box', 'Xerox 194', 0.37, 'West', 'California', 'Lakewood', 90712, datetime.datetime(2012, 7, 12, 0, 0), datetime.datetime(2012, 7, 17, 0, 0), 346.7043, 9, 502.47, 87659)
# (77, 23505, 'Critical', 0.0, 8.09, 7.96, 27, 'Guy Gallagher', 'Express Air', 'Corporate', 'Furniture', 'Office Furnishings', 'Small Box', '6" Cubicle Wall Clock, Black', 0.49, 'West', 'California', 'Lakewood', 90712, datetime.datetime(2012, 10, 26, 0, 0), datetime.datetime(2012, 10, 26, 0, 0), -171.2664, 23, 204.57, 87661)
# (78, 23506, 'Critical', 0.06, 14.2, 5.3, 27, 'Guy Gallagher', 'Regular Air', 'Corporate', 'Furniture', 'Office Furnishings', 'Wrap Bag', 'Coloredge Poster Frame', 0.46, 'West', 'California', 'Lakewood', 90712, datetime.datetime(2012, 10, 26, 0, 0), datetime.datetime(2012, 10, 28, 0, 0), 33.4144, 11, 161.11, 87661)
# (79, 23968, 'Not Specified', 0.01, 65.99, 8.99, 27, 'Guy Gallagher', 'Regular Air', 'Corporate', 'Technology', 'Telephones and Communication', 'Small Box', 'SC-3160', 0.59, 'West', 'California', 'Lakewood', 90712, datetime.datetime(2013, 11, 2, 0, 0), datetime.datetime(2013, 11, 4, 0, 0), 847.943712, 29, 1730.04, 87668)
# (80, 24987, 'High', 0.06, 2.88, 0.7, 28, 'Ronnie McNamara', 'Regular Air', 'Corporate', 'Office Supplies', 'Pens & Art Supplies', 'Wrap Bag', 'Newell 346', 0.56, 'West', 'California', 'Lancaster', 93534, datetime.datetime(2011, 1, 22, 0, 0), datetime.datetime(2011, 1, 23, 0, 0), -2.2072, 1, 3.41, 87653)
# (81, 24074, 'Critical', 0.07, 225.04, 11.79, 28, 'Ronnie McNamara', 'Regular Air', 'Corporate', 'Office Supplies', 'Appliances', 'Medium Box', 'Holmes Harmony HEPA Air Purifier for 17 x 20 Room', 0.42, 'West', 'California', 'Lancaster', 93534, datetime.datetime(2013, 4, 14, 0, 0), datetime.datetime(2013, 4, 16, 0, 0), 28.81, 1, 226.03, 87665)
# (82, 25324, 'Not Specified', 0.08, 65.99, 3.9, 29, 'Elizabeth Walker', 'Regular Air', 'Corporate', 'Technology', 'Telephones and Communication', 'Small Box', 'StarTAC Series', 0.55, 'West', 'California', 'Lawndale', 90260, datetime.datetime(2011, 1, 30, 0, 0), datetime.datetime(2011, 2, 1, 0, 0), -120.52304, 3, 164.1, 87654)
# (83, 25323, 'Not Specified', 0.08, 3.08, 0.99, 29, 'Elizabeth Walker', 'Regular Air', 'Corporate', 'Office Supplies', 'Labels', 'Small Box', 'Avery 481', 0.37, 'West', 'California', 'Lawndale', 90260, datetime.datetime(2013, 1, 30, 0, 0), datetime.datetime(2013, 1, 31, 0, 0), -1.6864000000000001, 1, 3.85, 87664)
# (84, 18877, 'High', 0.01, 6.48, 6.65, 31, 'Alice Capps', 'Regular Air', 'Corporate', 'Office Supplies', 'Paper', 'Small Box', 'Xerox 1966', 0.36, 'West', 'Oregon', 'Eugene', 97405, datetime.datetime(2012, 8, 11, 0, 0), datetime.datetime(2012, 8, 13, 0, 0), -43.3316, 15, 99.56, 89206)
# (85, 23509, 'High', 0.08, 34.99, 7.73, 32, 'Matthew Berman', 'Regular Air', 'Corporate', 'Office Supplies', 'Pens & Art Supplies', 'Small Box', 'Hunt Boston® Vacuum Mount KS Pencil Sharpener', 0.59, 'West', 'Oregon', 'Grants Pass', 97526, datetime.datetime(2010, 2, 22, 0, 0), datetime.datetime(2010, 2, 23, 0, 0), 144.69, 13, 424.68, 89199)
# (86, 23612, 'High', 0.01, 17.98, 8.51, 32, 'Matthew Berman', 'Regular Air', 'Corporate', 'Technology', 'Office Machines', 'Medium Box', 'Canon P1-DHIII Palm Printing Calculator', 0.4, 'West', 'Oregon', 'Grants Pass', 97526, datetime.datetime(2010, 3, 27, 0, 0), datetime.datetime(2010, 3, 28, 0, 0), -35.8788, 2, 40.17, 89200)
# (87, 23278, 'Medium', 0.09, 125.99, 7.69, 32, 'Matthew Berman', 'Express Air', 'Corporate', 'Technology', 'Telephones and Communication', 'Small Box', 'StarTAC 3000', 0.59, 'West', 'Oregon', 'Grants Pass', 97526, datetime.datetime(2010, 7, 20, 0, 0), datetime.datetime(2010, 7, 22, 0, 0), 209.997, 8, 783.55, 89202)
# (88, 19355, 'Low', 0.06, 205.99, 8.99, 32, 'Matthew Berman', 'Regular Air', 'Corporate', 'Technology', 'Telephones and Communication', 'Small Box', 'TimeportP7382', 0.56, 'West', 'Oregon', 'Grants Pass', 97526, datetime.datetime(2010, 9, 12, 0, 0), datetime.datetime(2010, 9, 19, 0, 0), 2568.096, 22, 3838.14, 89203)
# (89, 21213, 'Critical', 0.08, 8.95, 2.01, 32, 'Matthew Berman', 'Regular Air', 'Corporate', 'Office Supplies', 'Paper', 'Wrap Bag', 'Recycled Desk Saver Line "While You Were Out" Book, 5 1/2" X 4"', 0.39, 'West', 'Oregon', 'Grants Pass', 97526, datetime.datetime(2011, 10, 6, 0, 0), datetime.datetime(2011, 10, 8, 0, 0), 85.86359999999999, 15, 133.07, 89204)
# (90, 22221, 'High', 0.06, 449.99, 49.0, 32, 'Matthew Berman', 'Delivery Truck', 'Corporate', 'Technology', 'Copiers and Fax', 'Jumbo Drum', 'Canon PC940 Copier', 0.38, 'West', 'Oregon', 'Grants Pass', 97526, datetime.datetime(2013, 6, 12, 0, 0), datetime.datetime(2013, 6, 14, 0, 0), 345.0, 5, 2157.25, 89207)
# (91, 23654, 'Not Specified', 0.03, 4.24, 5.41, 33, 'Ricky Hensley', 'Regular Air', 'Corporate', 'Office Supplies', 'Binders and Binder Accessories', 'Small Box', 'Storex DuraTech Recycled Plastic Frosted Binders', 0.35, 'West', 'Oregon', 'Gresham', 97030, datetime.datetime(2010, 6, 15, 0, 0), datetime.datetime(2010, 6, 17, 0, 0), -84.4376, 13, 58.68, 89201)
# (92, 23655, 'Not Specified', 0.04, 2.94, 0.7, 33, 'Ricky Hensley', 'Regular Air', 'Corporate', 'Office Supplies', 'Pens & Art Supplies', 'Wrap Bag', 'Newell 338', 0.58, 'West', 'Oregon', 'Gresham', 97030, datetime.datetime(2010, 6, 15, 0, 0), datetime.datetime(2010, 6, 16, 0, 0), 24.312, 18, 53.1, 89201)
# (93, 25327, 'Medium', 0.05, 4.82, 5.24, 33, 'Ricky Hensley', 'Regular Air', 'Corporate', 'Office Supplies', 'Binders and Binder Accessories', 'Small Box', 'Wilson Jones Turn Tabs Binder Tool for Ring Binders', 0.39, 'West', 'Oregon', 'Gresham', 97030, datetime.datetime(2012, 1, 26, 0, 0), datetime.datetime(2012, 1, 27, 0, 0), -75.12168, 5, 24.27, 89205)
# (94, 24531, 'Critical', 0.05, 70.98, 30.0, 33, 'Ricky Hensley', 'Delivery Truck', 'Corporate', 'Furniture', 'Chairs & Chairmats', 'Jumbo Drum', 'Novimex High-Tech Fabric Mesh Task Chair', 0.78, 'West', 'Oregon', 'Gresham', 97030, datetime.datetime(2013, 8, 16, 0, 0), datetime.datetime(2013, 8, 18, 0, 0), -162.15032000000002, 9, 640.97, 89208)
# (95, 24532, 'Critical', 0.05, 4.98, 4.7, 33, 'Ricky Hensley', 'Regular Air', 'Corporate', 'Office Supplies', 'Paper', 'Small Box', 'Staples Copy Paper (20Lb. and 84 Bright)', 0.38, 'West', 'Oregon', 'Gresham', 97030, datetime.datetime(2013, 8, 16, 0, 0), datetime.datetime(2013, 8, 18, 0, 0), -14.992640000000002, 9, 46.63, 89208)
# (96, 25223, 'Not Specified', 0.0, 6783.02, 24.49, 35, 'Milton Bland', 'Regular Air', 'Small Business', 'Technology', 'Office Machines', 'Large Box', 'Polycom ViewStation™ ISDN Videoconferencing Unit', 0.39, 'West', 'Oregon', 'Gresham', 97030, datetime.datetime(2012, 11, 27, 0, 0), datetime.datetime(2012, 11, 28, 0, 0), 2396.8795800000025, 3, 21366.51, 91256)
# (97, 21026, 'Low', 0.07, 65.99, 3.99, 35, 'Milton Bland', 'Regular Air', 'Small Business', 'Technology', 'Telephones and Communication', 'Small Box', 'StarTAC 7760', 0.59, 'West', 'Oregon', 'Gresham', 97030, datetime.datetime(2013, 5, 28, 0, 0), datetime.datetime(2013, 6, 2, 0, 0), 165.50099999999998, 7, 394.37, 91257)
# (98, 25224, 'Not Specified', 0.02, 9.27, 4.39, 36, 'Ray Morgan', 'Express Air', 'Small Business', 'Office Supplies', 'Paper', 'Wrap Bag', 'Wirebound Message Books, Four 2 3/4" x 5" Forms per Page, 600 Sets per Book', 0.38, 'West', 'Oregon', 'Hillsboro', 97123, datetime.datetime(2012, 11, 27, 0, 0), datetime.datetime(2012, 11, 29, 0, 0), 71.434, 29, 272.98, 91256)
# (99, 25225, 'Not Specified', 0.03, 6.68, 6.15, 36, 'Ray Morgan', 'Regular Air', 'Small Business', 'Office Supplies', 'Paper', 'Small Box', 'Xerox 1968', 0.37, 'West', 'Oregon', 'Hillsboro', 97123, datetime.datetime(2012, 11, 27, 0, 0), datetime.datetime(2012, 11, 29, 0, 0), 5.650000000000006, 10, 73.81, 91256)
# (100, 25226, 'Not Specified', 0.1, 5.78, 5.67, 37, 'Stacy Chandler', 'Regular Air', 'Small Business', 'Office Supplies', 'Paper', 'Small Box', 'Xerox 1978', 0.36, 'West', 'Oregon', 'Keizer', 97303, datetime.datetime(2012, 11, 27, 0, 0), datetime.datetime(2012, 11, 30, 0, 0), 7.670000000000009, 11, 62.59, 91256)
# (101, 20935, 'Medium', 0.02, 1.68, 1.57, 39, "Ian L O'Donnell", 'Regular Air', 'Corporate', 'Office Supplies', 'Pens & Art Supplies', 'Wrap Bag', 'Newell 323', 0.59, 'Central', 'Illinois', 'Alton', 62002, datetime.datetime(2011, 7, 3, 0, 0), datetime.datetime(2011, 7, 4, 0, 0), -30.54, 10, 17.12, 88682)
# (102, 20936, 'Medium', 0.1, 7.08, 2.35, 39, "Ian L O'Donnell", 'Regular Air', 'Corporate', 'Office Supplies', 'Pens & Art Supplies', 'Wrap Bag', 'SANFORD Major Accent™ Highlighters', 0.47, 'Central', 'Illinois', 'Alton', 62002, datetime.datetime(2011, 7, 3, 0, 0), datetime.datetime(2011, 7, 5, 0, 0), 23.82, 14, 90.8, 88682)
# (103, 18911, 'Critical', 0.07, 28.15, 8.99, 39, "Ian L O'Donnell", 'Express Air', 'Corporate', 'Office Supplies', 'Pens & Art Supplies', 'Small Pack', 'Boston Electric Pencil Sharpener, Model 1818, Charcoal Black', 0.57, 'Central', 'Illinois', 'Alton', 62002, datetime.datetime(2013, 6, 12, 0, 0), datetime.datetime(2013, 6, 15, 0, 0), -15.463999999999999, 4, 113.59, 88684)
# (104, 18673, 'Not Specified', 0.09, 7.98, 6.5, 40, 'Seth Grimes', 'Regular Air', 'Corporate', 'Office Supplies', 'Storage & Organization', 'Medium Box', 'Iris Project Case', 0.59, 'West', 'Washington', 'Anacortes', 98221, datetime.datetime(2013, 3, 21, 0, 0), datetime.datetime(2013, 3, 23, 0, 0), -71.44, 4, 30.96, 88683)
# (105, 22406, 'Not Specified', 0.09, 45.99, 4.99, 42, 'Alexandra Fuller', 'Regular Air', 'Consumer', 'Technology', 'Telephones and Communication', 'Small Box', 'KF 788', 0.56, 'West', 'Washington', 'Puyallup', 98373, datetime.datetime(2012, 11, 5, 0, 0), datetime.datetime(2012, 11, 6, 0, 0), 24.186800000000034, 8, 299.74, 91455)
# (106, 23753, 'Not Specified', 0.07, 8.09, 7.96, 42, 'Alexandra Fuller', 'Regular Air', 'Consumer', 'Furniture', 'Office Furnishings', 'Small Box', '6" Cubicle Wall Clock, Black', 0.49, 'West', 'Washington', 'Puyallup', 98373, datetime.datetime(2013, 11, 26, 0, 0), datetime.datetime(2013, 11, 29, 0, 0), 63.48448000000002, 36, 291.56, 91458)
# (107, 23754, 'Not Specified', 0.03, 20.99, 1.25, 42, 'Alexandra Fuller', 'Regular Air', 'Consumer', 'Technology', 'Telephones and Communication', 'Small Pack', 'Accessory29', 0.83, 'West', 'Washington', 'Puyallup', 98373, datetime.datetime(2013, 11, 26, 0, 0), datetime.datetime(2013, 11, 27, 0, 0), 43.27171200000002, 9, 158.27, 91458)
# (108, 25933, 'High', 0.0, 99.99, 19.99, 43, 'Theodore Moran', 'Regular Air', 'Consumer', 'Technology', 'Office Machines', 'Small Box', 'AT&T 2230 Dual Handset Phone With Caller ID/Call Waiting', 0.52, 'West', 'Washington', 'Redmond', 98052, datetime.datetime(2010, 11, 10, 0, 0), datetime.datetime(2010, 11, 11, 0, 0), 25.913820000000015, 6, 647.07, 91454)
# (109, 25438, 'Low', 0.05, 9.31, 3.98, 43, 'Theodore Moran', 'Regular Air', 'Consumer', 'Office Supplies', 'Scissors, Rulers and Trimmers', 'Small Pack', 'Acme® Forged Steel Scissors with Black Enamel Handles', 0.56, 'West', 'Washington', 'Redmond', 98052, datetime.datetime(2013, 2, 26, 0, 0), datetime.datetime(2013, 3, 4, 0, 0), -17.58, 9, 83.01, 91456)
# (110, 25331, 'Critical', 0.06, 95.98, 58.2, 43, 'Theodore Moran', 'Delivery Truck', 'Consumer', 'Furniture', 'Chairs & Chairmats', 'Jumbo Drum', 'Global Deluxe Office Fabric Chairs', 0.58, 'West', 'Washington', 'Redmond', 98052, datetime.datetime(2013, 8, 30, 0, 0), datetime.datetime(2013, 9, 1, 0, 0), -336.38464000000005, 15, 1396.96, 91457)
# (111, 23651, 'Medium', 0.1, 39.48, 3.99, 45, 'Melinda Sloan', 'Regular Air', 'Home Office', 'Office Supplies', 'Appliances', 'Small Box', 'Belkin 7 Outlet SurgeMaster Surge Protector with Phone Protection', 0.56, 'Central', 'Texas', 'Coppell', 75019, datetime.datetime(2012, 2, 24, 0, 0), datetime.datetime(2012, 2, 26, 0, 0), 338.6244, 13, 490.76, 91578)
# (112, 25399, 'Not Specified', 0.08, 5.81, 3.37, 45, 'Melinda Sloan', 'Regular Air', 'Home Office', 'Office Supplies', 'Rubber Bands', 'Wrap Bag', 'Advantus Push Pins, Aluminum Head', 0.54, 'Central', 'Texas', 'Coppell', 75019, datetime.datetime(2012, 9, 23, 0, 0), datetime.datetime(2012, 9, 23, 0, 0), -51.25, 18, 97.85, 91579)
# (113, 25397, 'Not Specified', 0.0, 30.97, 4.0, 46, 'Anne Nguyen', 'Regular Air', 'Home Office', 'Technology', 'Computer Peripherals', 'Small Box', 'Microsoft Multimedia Keyboard', 0.74, 'South', 'Virginia', 'Colonial Heights', 23834, datetime.datetime(2012, 9, 23, 0, 0), datetime.datetime(2012, 9, 25, 0, 0), 21.624, 3, 94.62, 91579)
# (114, 25398, 'Not Specified', 0.0, 17.67, 8.99, 46, 'Anne Nguyen', 'Regular Air', 'Home Office', 'Furniture', 'Office Furnishings', 'Small Pack', 'Executive Impressions 12" Wall Clock', 0.47, 'South', 'Virginia', 'Colonial Heights', 23834, datetime.datetime(2012, 9, 23, 0, 0), datetime.datetime(2012, 9, 25, 0, 0), -78.092, 20, 368.39, 91579)
# (115, 20727, 'Medium', 0.06, 17.98, 8.51, 48, 'Geoffrey Hewitt', 'Regular Air', 'Corporate', 'Technology', 'Office Machines', 'Medium Box', 'Canon P1-DHIII Palm Printing Calculator', 0.4, 'Central', 'Illinois', 'Springfield', 62701, datetime.datetime(2011, 8, 15, 0, 0), datetime.datetime(2011, 8, 15, 0, 0), -27.600924, 1, 21.16, 87712)
# (116, 19337, 'Medium', 0.07, 4.13, 0.5, 48, 'Geoffrey Hewitt', 'Regular Air', 'Corporate', 'Office Supplies', 'Labels', 'Small Box', 'Avery 506', 0.39, 'Central', 'Illinois', 'Springfield', 62701, datetime.datetime(2012, 8, 13, 0, 0), datetime.datetime(2012, 8, 16, 0, 0), 60.80969999999999, 22, 88.13, 87713)
# (117, 18362, 'High', 0.03, 7.31, 0.49, 48, 'Geoffrey Hewitt', 'Regular Air', 'Corporate', 'Office Supplies', 'Labels', 'Small Box', 'Self-Adhesive Address Labels for Typewriters by Universal', 0.38, 'Central', 'Illinois', 'Springfield', 62701, datetime.datetime(2012, 10, 10, 0, 0), datetime.datetime(2012, 10, 11, 0, 0), 94.81979999999999, 19, 137.42, 87714)
# (118, 18363, 'High', 0.01, 20.99, 2.5, 48, 'Geoffrey Hewitt', 'Regular Air', 'Corporate', 'Technology', 'Telephones and Communication', 'Wrap Bag', 'Accessory37', 0.81, 'Central', 'Illinois', 'Springfield', 62701, datetime.datetime(2012, 10, 10, 0, 0), datetime.datetime(2012, 10, 11, 0, 0), -85.27464, 12, 213.02, 87714)
# (119, 20726, 'High', 0.06, 39.24, 1.99, 48, 'Geoffrey Hewitt', 'Regular Air', 'Corporate', 'Technology', 'Computer Peripherals', 'Small Pack', 'Verbatim DVD-R 4.7GB authoring disc', 0.51, 'Central', 'Illinois', 'Springfield', 62701, datetime.datetime(2013, 1, 11, 0, 0), datetime.datetime(2013, 1, 12, 0, 0), 229.0593, 9, 331.97, 87715)
# (120, 23944, 'High', 0.08, 67.84, 0.99, 49, 'Terri Lyons', 'Regular Air', 'Corporate', 'Office Supplies', 'Appliances', 'Small Box', 'Fellowes Command Center 5-outlet power strip', 0.58, 'Central', 'Illinois', 'Streamwood', 60107, datetime.datetime(2011, 3, 29, 0, 0), datetime.datetime(2011, 3, 29, 0, 0), -12.82, 1, 64.91, 87710)
# (121, 21138, 'High', 0.04, 7.64, 1.39, 49, 'Terri Lyons', 'Express Air', 'Corporate', 'Office Supplies', 'Envelopes', 'Small Box', '#10- 4 1/8" x 9 1/2" Security-Tint Envelopes', 0.36, 'Central', 'Illinois', 'Streamwood', 60107, datetime.datetime(2011, 5, 18, 0, 0), datetime.datetime(2011, 5, 19, 0, 0), 7.27, 1, 15.42, 87711)
# (122, 20728, 'Medium', 0.04, 12.95, 4.98, 49, 'Terri Lyons', 'Regular Air', 'Corporate', 'Office Supplies', 'Binders and Binder Accessories', 'Small Box', 'GBC Binding covers', 0.4, 'Central', 'Illinois', 'Streamwood', 60107, datetime.datetime(2011, 8, 15, 0, 0), datetime.datetime(2011, 8, 17, 0, 0), 18.882579999999997, 5, 69.4, 87712)
# (123, 23662, 'Low', 0.0, 65.99, 5.31, 49, 'Terri Lyons', 'Regular Air', 'Corporate', 'Technology', 'Telephones and Communication', 'Small Box', '3390', 0.57, 'Central', 'Illinois', 'Streamwood', 60107, datetime.datetime(2013, 2, 17, 0, 0), datetime.datetime(2013, 2, 19, 0, 0), 391.7199, 10, 567.71, 87716)
# (124, 23802, 'Medium', 0.1, 30.73, 4.0, 49, 'Terri Lyons', 'Regular Air', 'Corporate', 'Technology', 'Computer Peripherals', 'Small Box', 'Fellowes 17-key keypad for PS/2 interface', 0.75, 'Central', 'Illinois', 'Streamwood', 60107, datetime.datetime(2013, 3, 2, 0, 0), datetime.datetime(2013, 3, 3, 0, 0), -45.1, 7, 208.12, 87717)
# (125, 21300, 'Critical', 0.06, 200.97, 15.59, 49, 'Terri Lyons', 'Delivery Truck', 'Corporate', 'Technology', 'Office Machines', 'Jumbo Drum', 'Hewlett-Packard Deskjet 6122 Color Inkjet Printer', 0.36, 'Central', 'Illinois', 'Streamwood', 60107, datetime.datetime(2013, 3, 12, 0, 0), datetime.datetime(2013, 3, 14, 0, 0), 526.608, 4, 763.2, 87718)
# (126, 22691, 'Medium', 0.09, 2.6, 2.4, 49, 'Terri Lyons', 'Regular Air', 'Corporate', 'Office Supplies', 'Pens & Art Supplies', 'Wrap Bag', '12 Colored Short Pencils', 0.58, 'Central', 'Illinois', 'Streamwood', 60107, datetime.datetime(2013, 10, 6, 0, 0), datetime.datetime(2013, 10, 7, 0, 0), -17.68, 6, 16.64, 87719)
# (127, 22692, 'Medium', 0.07, 14.97, 7.51, 49, 'Terri Lyons', 'Regular Air', 'Corporate', 'Office Supplies', 'Storage & Organization', 'Small Box', 'Pizazz® Global Quick File™', 0.57, 'Central', 'Illinois', 'Streamwood', 60107, datetime.datetime(2013, 10, 6, 0, 0), datetime.datetime(2013, 10, 8, 0, 0), -30.48, 4, 63.9, 87719)
# (128, 23945, 'High', 0.04, 276.2, 24.49, 50, 'Dawn Bailey', 'Regular Air', 'Corporate', 'Furniture', 'Chairs & Chairmats', 'Large Box', 'SAFCO Arco Folding Chair', None, 'Central', 'Illinois', 'Tinley Park', 60477, datetime.datetime(2011, 3, 29, 0, 0), datetime.datetime(2011, 4, 1, 0, 0), 1585.0886999999998, 8, 2297.23, 87710)
# (129, 18551, 'Not Specified', 0.0, 115.99, 2.5, 52, 'Lorraine Kelly', 'Regular Air', 'Corporate', 'Technology', 'Telephones and Communication', 'Small Box', '6160', 0.57, 'West', 'Washington', 'Puyallup', 98373, datetime.datetime(2010, 9, 10, 0, 0), datetime.datetime(2010, 9, 10, 0, 0), 162.666, 6, 627.04, 88426)
# (130, 19341, 'Critical', 0.02, 40.97, 1.99, 52, 'Lorraine Kelly', 'Regular Air', 'Corporate', 'Technology', 'Computer Peripherals', 'Small Pack', 'TDK 4.7GB DVD-R Spindle, 15/Pack', 0.42, 'West', 'Washington', 'Puyallup', 98373, datetime.datetime(2011, 9, 10, 0, 0), datetime.datetime(2011, 9, 11, 0, 0), 378.16139999999996, 13, 548.06, 88427)
# (131, 18666, 'Critical', 0.08, 7.7, 3.68, 52, 'Lorraine Kelly', 'Regular Air', 'Corporate', 'Furniture', 'Office Furnishings', 'Wrap Bag', 'Deflect-O® Glasstique™ Clear Desk Accessories', 0.52, 'West', 'Washington', 'Puyallup', 98373, datetime.datetime(2012, 11, 6, 0, 0), datetime.datetime(2012, 11, 7, 0, 0), 3.328000000000003, 17, 129.57, 88428)
# (132, 22117, 'Critical', 0.07, 3502.14, 8.73, 53, 'Sidney Russell Austin', 'Delivery Truck', 'Corporate', 'Technology', 'Office Machines', 'Jumbo Box', 'Okidata Pacemark 4410N Wide Format Dot Matrix Printer', 0.57, 'West', 'Washington', 'Redmond', 98052, datetime.datetime(2010, 7, 28, 0, 0), datetime.datetime(2010, 7, 30, 0, 0), -6923.5992, 1, 3267.55, 88425)
# (133, 18552, 'Not Specified', 0.02, 5.98, 5.79, 53, 'Sidney Russell Austin', 'Regular Air', 'Corporate', 'Office Supplies', 'Paper', 'Small Box', 'Xerox 1903', 0.36, 'West', 'Washington', 'Redmond', 98052, datetime.datetime(2010, 9, 10, 0, 0), datetime.datetime(2010, 9, 11, 0, 0), -67.49, 17, 110.19, 88426)
# (134, 21677, 'Low', 0.09, 3.08, 0.99, 53, 'Sidney Russell Austin', 'Regular Air', 'Corporate', 'Office Supplies', 'Labels', 'Small Box', 'Avery 481', 0.37, 'West', 'Washington', 'Redmond', 98052, datetime.datetime(2013, 2, 19, 0, 0), datetime.datetime(2013, 2, 21, 0, 0), 23.1564, 11, 33.56, 88429)
# (135, 19968, 'High', 0.03, 44.43, 46.59, 55, 'Marvin Hawley', 'Delivery Truck', 'Home Office', 'Furniture', 'Tables', 'Jumbo Box', 'Hon 61000 Series Interactive Training Tables', 0.67, 'East', 'New York', 'Syracuse', 13210, datetime.datetime(2011, 10, 6, 0, 0), datetime.datetime(2011, 10, 7, 0, 0), -1513.2648960000004, 14, 666.63, 88076)
# (136, 19969, 'Low', 0.07, 130.98, 54.74, 55, 'Marvin Hawley', 'Delivery Truck', 'Consumer', 'Furniture', 'Bookcases', 'Jumbo Box', "O'Sullivan Elevations Bookcase, Cherry Finish", 0.69, 'East', 'New York', 'Syracuse', 13210, datetime.datetime(2011, 10, 20, 0, 0), datetime.datetime(2011, 10, 25, 0, 0), -414.18, 6, 814.6, 88077)
# (137, 18469, 'Low', 0.01, 15.68, 3.73, 55, 'Marvin Hawley', 'Regular Air', 'Consumer', 'Furniture', 'Office Furnishings', 'Small Pack', 'Artistic Insta-Plaque', 0.46, 'East', 'New York', 'Syracuse', 13210, datetime.datetime(2013, 4, 10, 0, 0), datetime.datetime(2013, 4, 10, 0, 0), 23.563499999999998, 2, 34.15, 88081)
# (138, 18470, 'Low', 0.04, 71.37, 69.0, 55, 'Marvin Hawley', 'Express Air', 'Consumer', 'Furniture', 'Tables', 'Large Box', 'Lesro Sheffield Collection Coffee Table, End Table, Center Table, Corner Table', 0.68, 'East', 'New York', 'Syracuse', 13210, datetime.datetime(2013, 4, 10, 0, 0), datetime.datetime(2013, 4, 14, 0, 0), 54.59805000000001, 11, 761.52, 88081)
# (139, 20697, 'Medium', 0.06, 3.8, 1.49, 56, 'Randall Montgomery', 'Regular Air', 'Consumer', 'Office Supplies', 'Binders and Binder Accessories', 'Small Box', 'Durable Pressboard Binders', 0.38, 'East', 'New York', 'Tonawanda', 14150, datetime.datetime(2010, 10, 20, 0, 0), datetime.datetime(2010, 10, 21, 0, 0), 19.6282, 20, 73.55, 88075)
# (140, 20698, 'Medium', 0.06, 1.76, 0.7, 56, 'Randall Montgomery', 'Regular Air', 'Consumer', 'Office Supplies', 'Pens & Art Supplies', 'Wrap Bag', 'Newell 310', 0.56, 'East', 'New York', 'Tonawanda', 14150, datetime.datetime(2010, 10, 20, 0, 0), datetime.datetime(2010, 10, 21, 0, 0), -1.6524, 17, 29.57, 88075)
# (141, 19970, 'Low', 0.04, 4.76, 3.01, 56, 'Randall Montgomery', 'Regular Air', 'Consumer', 'Office Supplies', 'Paper', 'Wrap Bag', 'TOPS Voice Message Log Book, Flash Format', 0.36, 'East', 'New York', 'Tonawanda', 14150, datetime.datetime(2011, 10, 20, 0, 0), datetime.datetime(2011, 10, 27, 0, 0), -7.9488, 23, 109.64, 88077)
# (142, 24218, 'High', 0.01, 5.84, 1.2, 56, 'Randall Montgomery', 'Express Air', 'Consumer', 'Office Supplies', 'Pens & Art Supplies', 'Wrap Bag', 'Newell 312', 0.55, 'East', 'New York', 'Tonawanda', 14150, datetime.datetime(2013, 1, 11, 0, 0), datetime.datetime(2013, 1, 13, 0, 0), 47.0972, 11, 68.79, 88079)
# (143, 23305, 'Not Specified', 0.1, 5.94, 9.92, 56, 'Randall Montgomery', 'Regular Air', 'Consumer', 'Office Supplies', 'Binders and Binder Accessories', 'Small Box', 'Storex Dura Pro™ Binders', 0.38, 'East', 'New York', 'Tonawanda', 14150, datetime.datetime(2013, 2, 8, 0, 0), datetime.datetime(2013, 2, 9, 0, 0), -211.0595, 7, 40.94, 88080)
# (144, 23306, 'Not Specified', 0.1, 65.99, 2.5, 56, 'Randall Montgomery', 'Regular Air', 'Consumer', 'Technology', 'Telephones and Communication', 'Small Box', '6190', 0.55, 'East', 'New York', 'Tonawanda', 14150, datetime.datetime(2013, 2, 8, 0, 0), datetime.datetime(2013, 2, 9, 0, 0), 186.417, 6, 311.98, 88080)
# ...
# (8465, 6041, 'Medium', 0.05, 4.28, 6.18, 3075, 'Gordon Brandt', 'Express Air', 'Corporate', 'Office Supplies', 'Paper', 'Small Box', 'Xerox 1980', 0.4, 'West', 'California', 'Los Angeles', 90061, datetime.datetime(2013, 6, 25, 0, 0), datetime.datetime(2013, 6, 27, 0, 0), -22.56, 12, 73.71, 42823)
# (8466, 4444, 'Not Specified', 0.02, 5.28, 5.66, 3075, 'Gordon Brandt', 'Regular Air', 'Corporate', 'Office Supplies', 'Paper', 'Small Box', 'Xerox 4200 Series MultiUse Premium Copy Paper (20Lb. and 84 Bright)', 0.4, 'West', 'California', 'Los Angeles', 90061, datetime.datetime(2013, 11, 7, 0, 0), datetime.datetime(2013, 11, 8, 0, 0), -93.78, 137, 764.75, 31681)
# (8467, 19739, 'Medium', 0.0, 137.48, 32.18, 3076, 'Peter Hardy', 'Delivery Truck', 'Small Business', 'Furniture', 'Bookcases', 'Jumbo Box', "O'Sullivan Cherrywood Estates Traditional Barrister Bookcase", 0.78, 'East', 'Ohio', 'Stow', 44224, datetime.datetime(2010, 7, 7, 0, 0), datetime.datetime(2010, 7, 8, 0, 0), -203.27, 2, 296.75, 88241)
# (8468, 20061, 'High', 0.09, 3.85, 0.7, 3076, 'Peter Hardy', 'Regular Air', 'Consumer', 'Office Supplies', 'Pens & Art Supplies', 'Wrap Bag', 'Avery Hi-Liter Pen Style Six-Color Fluorescent Set', 0.44, 'East', 'Ohio', 'Stow', 44224, datetime.datetime(2011, 1, 5, 0, 0), datetime.datetime(2011, 1, 5, 0, 0), 19.8513, 8, 28.77, 88242)
# (8469, 20062, 'High', 0.1, 65.99, 4.2, 3076, 'Peter Hardy', 'Express Air', 'Consumer', 'Technology', 'Telephones and Communication', 'Small Box', '5170', 0.59, 'East', 'Ohio', 'Stow', 44224, datetime.datetime(2011, 1, 5, 0, 0), datetime.datetime(2011, 1, 7, 0, 0), 345.33108, 11, 580.7, 88242)
# (8470, 21130, 'Not Specified', 0.0, 20.98, 8.83, 3076, 'Peter Hardy', 'Regular Air', 'Small Business', 'Office Supplies', 'Binders and Binder Accessories', 'Small Box', 'Premium Transparent Presentation Covers by GBC', 0.37, 'East', 'Ohio', 'Stow', 44224, datetime.datetime(2011, 6, 10, 0, 0), datetime.datetime(2011, 6, 10, 0, 0), 49.827, 5, 115.4, 88243)
# (8471, 21131, 'Not Specified', 0.03, 5.68, 1.46, 3076, 'Peter Hardy', 'Regular Air', 'Small Business', 'Office Supplies', 'Paper', 'Wrap Bag', 'Adams Write n\' Stick Phone Message Book, 11" X 5 1/4", 200 Messages', 0.39, 'East', 'Ohio', 'Stow', 44224, datetime.datetime(2011, 6, 10, 0, 0), datetime.datetime(2011, 6, 11, 0, 0), 15.972000000000001, 4, 23.67, 88243)
# (8472, 19910, 'High', 0.05, 14.48, 1.99, 3076, 'Peter Hardy', 'Regular Air', 'Consumer', 'Technology', 'Computer Peripherals', 'Small Pack', 'TDK 4.7GB DVD+RW', 0.49, 'East', 'Ohio', 'Stow', 44224, datetime.datetime(2012, 9, 30, 0, 0), datetime.datetime(2012, 10, 2, 0, 0), 165.2, 24, 334.42, 88246)
# (8473, 18500, 'High', 0.08, 5.98, 4.69, 3076, 'Peter Hardy', 'Regular Air', 'Consumer', 'Office Supplies', 'Storage & Organization', 'Small Box', 'Perma STOR-ALL™ Hanging File Box, 13 1/8"W x 12 1/4"D x 10 1/2"H', 0.68, 'East', 'Ohio', 'Stow', 44224, datetime.datetime(2012, 10, 2, 0, 0), datetime.datetime(2012, 10, 4, 0, 0), -102.762, 13, 73.78, 88247)
# (8474, 20616, 'Critical', 0.08, 2.08, 1.49, 3076, 'Peter Hardy', 'Regular Air', 'Small Business', 'Office Supplies', 'Binders and Binder Accessories', 'Small Box', 'Round Ring Binders', 0.38, 'East', 'Ohio', 'Stow', 44224, datetime.datetime(2013, 5, 3, 0, 0), datetime.datetime(2013, 5, 5, 0, 0), -8.3605, 5, 10.29, 88248)
# (8475, 23816, 'Medium', 0.07, 300.97, 7.18, 3077, 'Lynne Reid', 'Regular Air', 'Small Business', 'Technology', 'Computer Peripherals', 'Small Box', 'Gyration Ultra Professional Cordless Optical Suite', 0.48, 'East', 'Ohio', 'Strongsville', 44136, datetime.datetime(2010, 5, 7, 0, 0), datetime.datetime(2010, 5, 9, 0, 0), -807.59, 2, 582.2, 88239)
# (8476, 21132, 'Not Specified', 0.0, 7.96, 4.95, 3077, 'Lynne Reid', 'Regular Air', 'Small Business', 'Furniture', 'Office Furnishings', 'Small Box', 'Staples Plastic Wall Frames', 0.41, 'East', 'Ohio', 'Strongsville', 44136, datetime.datetime(2011, 6, 10, 0, 0), datetime.datetime(2011, 6, 12, 0, 0), 28.332, 7, 60.33, 88243)
# (8477, 21968, 'Medium', 0.03, 3.08, 0.99, 3077, 'Lynne Reid', 'Regular Air', 'Consumer', 'Office Supplies', 'Labels', 'Small Box', 'Avery 511', 0.37, 'East', 'Ohio', 'Strongsville', 44136, datetime.datetime(2011, 8, 1, 0, 0), datetime.datetime(2011, 8, 1, 0, 0), 28.9938, 13, 42.02, 88244)
# (8478, 23007, 'High', 0.1, 100.97, 7.18, 3077, 'Lynne Reid', 'Regular Air', 'Consumer', 'Technology', 'Computer Peripherals', 'Small Box', 'Gyration Ultra Cordless Optical Suite', 0.46, 'East', 'Ohio', 'Strongsville', 44136, datetime.datetime(2013, 10, 23, 0, 0), datetime.datetime(2013, 10, 24, 0, 0), 1174.02, 22, 2059.18, 88250)
# (8479, 23008, 'High', 0.0, 5.28, 8.16, 3077, 'Lynne Reid', 'Regular Air', 'Consumer', 'Office Supplies', 'Paper', 'Small Box', 'Xerox 1963', 0.4, 'East', 'Ohio', 'Strongsville', 44136, datetime.datetime(2013, 10, 23, 0, 0), datetime.datetime(2013, 10, 23, 0, 0), -122.21, 13, 73.06, 88250)
# (8480, 24695, 'Not Specified', 0.0, 83.98, 5.01, 3077, 'Lynne Reid', 'Regular Air', 'Small Business', 'Office Supplies', 'Envelopes', 'Small Box', 'Ames Color-File® Green Diamond Border X-ray Mailers', 0.38, 'East', 'Ohio', 'Strongsville', 44136, datetime.datetime(2013, 11, 16, 0, 0), datetime.datetime(2013, 11, 17, 0, 0), 1970.1707999999999, 34, 2855.32, 88251)
# (8481, 25489, 'Not Specified', 0.04, 35.44, 5.09, 3078, 'Kate McKenna', 'Regular Air', 'Small Business', 'Office Supplies', 'Paper', 'Small Box', 'Xerox 1932', 0.38, 'East', 'Ohio', 'Toledo', 43615, datetime.datetime(2010, 6, 11, 0, 0), datetime.datetime(2010, 6, 11, 0, 0), 118.6317, 5, 171.93, 88240)
# (8482, 25490, 'Not Specified', 0.08, 3.98, 0.7, 3078, 'Kate McKenna', 'Regular Air', 'Small Business', 'Office Supplies', 'Pens & Art Supplies', 'Wrap Bag', '4009® Highlighters by Sanford', 0.52, 'East', 'Ohio', 'Toledo', 43615, datetime.datetime(2010, 6, 11, 0, 0), datetime.datetime(2010, 6, 14, 0, 0), 23.304000000000002, 9, 35.19, 88240)
# (8483, 25957, 'Low', 0.03, 90.98, 30.0, 3078, 'Kate McKenna', 'Delivery Truck', 'Consumer', 'Furniture', 'Chairs & Chairmats', 'Jumbo Drum', 'Office Star - Task Chair with Contemporary Loop Arms', 0.61, 'East', 'Ohio', 'Toledo', 43615, datetime.datetime(2011, 12, 14, 0, 0), datetime.datetime(2011, 12, 18, 0, 0), -35.74, 5, 482.73, 88245)
# (8484, 25491, 'Not Specified', 0.01, 1.76, 0.7, 3078, 'Kate McKenna', 'Regular Air', 'Small Business', 'Office Supplies', 'Pens & Art Supplies', 'Wrap Bag', 'Newell 310', 0.56, 'East', 'Ohio', 'Toledo', 43615, datetime.datetime(2013, 6, 11, 0, 0), datetime.datetime(2013, 6, 12, 0, 0), 3.756, 18, 32.89, 88249)
# (8485, 25492, 'Not Specified', 0.01, 193.17, 19.99, 3078, 'Kate McKenna', 'Express Air', 'Small Business', 'Office Supplies', 'Storage & Organization', 'Small Box', 'Fellowes Staxonsteel® Drawer Files', 0.71, 'East', 'Ohio', 'Toledo', 43615, datetime.datetime(2013, 6, 11, 0, 0), datetime.datetime(2013, 6, 11, 0, 0), 1369.2839999999999, 16, 3096.12, 88249)
# (8486, 24807, 'Critical', 0.0, 2.21, 1.0, 3078, 'Kate McKenna', 'Express Air', 'Small Business', 'Office Supplies', 'Pens & Art Supplies', 'Wrap Bag', 'Quartet Alpha® White Chalk, 12/Pack', 0.38, 'East', 'Ohio', 'Toledo', 43615, datetime.datetime(2013, 12, 10, 0, 0), datetime.datetime(2013, 12, 11, 0, 0), 16.4082, 9, 23.78, 88252)
# (8487, 5816, 'Medium', 0.07, 300.97, 7.18, 3079, 'Andrew Levine', 'Regular Air', 'Small Business', 'Technology', 'Computer Peripherals', 'Small Box', 'Gyration Ultra Professional Cordless Optical Suite', 0.48, 'East', 'Pennsylvania', 'Philadelphia', 19112, datetime.datetime(2010, 5, 7, 0, 0), datetime.datetime(2010, 5, 9, 0, 0), -807.59, 7, 2037.69, 41253)
# (8488, 7489, 'Not Specified', 0.04, 35.44, 5.09, 3079, 'Andrew Levine', 'Regular Air', 'Small Business', 'Office Supplies', 'Paper', 'Small Box', 'Xerox 1932', 0.38, 'East', 'Pennsylvania', 'Philadelphia', 19112, datetime.datetime(2010, 6, 11, 0, 0), datetime.datetime(2010, 6, 11, 0, 0), 150.72, 21, 722.1, 53476)
# (8489, 7490, 'Not Specified', 0.08, 3.98, 0.7, 3079, 'Andrew Levine', 'Regular Air', 'Small Business', 'Office Supplies', 'Pens & Art Supplies', 'Wrap Bag', '4009® Highlighters by Sanford', 0.52, 'East', 'Pennsylvania', 'Philadelphia', 19112, datetime.datetime(2010, 6, 11, 0, 0), datetime.datetime(2010, 6, 14, 0, 0), 19.42, 36, 140.78, 53476)
# (8490, 7491, 'Not Specified', 0.01, 1.76, 0.7, 3079, 'Andrew Levine', 'Regular Air', 'Small Business', 'Office Supplies', 'Pens & Art Supplies', 'Wrap Bag', 'Newell 310', 0.56, 'East', 'Pennsylvania', 'Philadelphia', 19112, datetime.datetime(2010, 6, 11, 0, 0), datetime.datetime(2010, 6, 12, 0, 0), 3.13, 71, 129.72, 53476)
# (8491, 7492, 'Not Specified', 0.01, 193.17, 19.99, 3079, 'Andrew Levine', 'Express Air', 'Small Business', 'Office Supplies', 'Storage & Organization', 'Small Box', 'Fellowes Staxonsteel® Drawer Files', 0.71, 'East', 'Pennsylvania', 'Philadelphia', 19112, datetime.datetime(2010, 6, 11, 0, 0), datetime.datetime(2010, 6, 11, 0, 0), 1141.07, 63, 12190.98, 53476)
# (8492, 1739, 'Medium', 0.0, 137.48, 32.18, 3079, 'Andrew Levine', 'Delivery Truck', 'Small Business', 'Furniture', 'Bookcases', 'Jumbo Box', "O'Sullivan Cherrywood Estates Traditional Barrister Bookcase", 0.78, 'East', 'Pennsylvania', 'Philadelphia', 19112, datetime.datetime(2010, 7, 7, 0, 0), datetime.datetime(2010, 7, 8, 0, 0), -203.27, 10, 1483.76, 12480)
# (8493, 6807, 'Critical', 0.0, 2.21, 1.0, 3079, 'Andrew Levine', 'Express Air', 'Small Business', 'Office Supplies', 'Pens & Art Supplies', 'Wrap Bag', 'Quartet Alpha® White Chalk, 12/Pack', 0.38, 'East', 'Pennsylvania', 'Philadelphia', 19112, datetime.datetime(2010, 12, 10, 0, 0), datetime.datetime(2010, 12, 11, 0, 0), 10.01, 33, 87.18, 48483)
# (8494, 2061, 'High', 0.09, 3.85, 0.7, 3079, 'Andrew Levine', 'Regular Air', 'Consumer', 'Office Supplies', 'Pens & Art Supplies', 'Wrap Bag', 'Avery Hi-Liter Pen Style Six-Color Fluorescent Set', 0.44, 'East', 'Pennsylvania', 'Philadelphia', 19112, datetime.datetime(2011, 1, 5, 0, 0), datetime.datetime(2011, 1, 5, 0, 0), 11.828, 31, 111.48, 14755)
# (8495, 2062, 'High', 0.1, 65.99, 4.2, 3079, 'Andrew Levine', 'Express Air', 'Consumer', 'Technology', 'Telephones and Communication', 'Small Box', '5170', 0.59, 'East', 'Pennsylvania', 'Philadelphia', 19112, datetime.datetime(2011, 1, 5, 0, 0), datetime.datetime(2011, 1, 7, 0, 0), 181.7532, 44, 2322.81, 14755)
# (8496, 3130, 'Not Specified', 0.0, 20.98, 8.83, 3079, 'Andrew Levine', 'Regular Air', 'Small Business', 'Office Supplies', 'Binders and Binder Accessories', 'Small Box', 'Premium Transparent Presentation Covers by GBC', 0.37, 'East', 'Pennsylvania', 'Philadelphia', 19112, datetime.datetime(2011, 6, 10, 0, 0), datetime.datetime(2011, 6, 10, 0, 0), 41.5225, 21, 484.67, 22468)
# (8497, 3131, 'Not Specified', 0.03, 5.68, 1.46, 3079, 'Andrew Levine', 'Regular Air', 'Small Business', 'Office Supplies', 'Paper', 'Wrap Bag', 'Adams Write n\' Stick Phone Message Book, 11" X 5 1/4", 200 Messages', 0.39, 'East', 'Pennsylvania', 'Philadelphia', 19112, datetime.datetime(2011, 6, 10, 0, 0), datetime.datetime(2011, 6, 11, 0, 0), 13.31, 17, 100.61, 22468)
# (8498, 3132, 'Not Specified', 0.0, 7.96, 4.95, 3079, 'Andrew Levine', 'Regular Air', 'Small Business', 'Furniture', 'Office Furnishings', 'Small Box', 'Staples Plastic Wall Frames', 0.41, 'East', 'Pennsylvania', 'Philadelphia', 19112, datetime.datetime(2011, 6, 10, 0, 0), datetime.datetime(2011, 6, 12, 0, 0), 23.61, 29, 249.93, 22468)
# (8499, 3968, 'Medium', 0.03, 3.08, 0.99, 3079, 'Andrew Levine', 'Regular Air', 'Consumer', 'Office Supplies', 'Labels', 'Small Box', 'Avery 511', 0.37, 'East', 'Pennsylvania', 'Philadelphia', 19112, datetime.datetime(2011, 8, 1, 0, 0), datetime.datetime(2011, 8, 1, 0, 0), 24.71, 50, 161.61, 28321)
# (8500, 7957, 'Low', 0.03, 90.98, 30.0, 3079, 'Andrew Levine', 'Delivery Truck', 'Consumer', 'Furniture', 'Chairs & Chairmats', 'Jumbo Drum', 'Office Star - Task Chair with Contemporary Loop Arms', 0.61, 'East', 'Pennsylvania', 'Philadelphia', 19112, datetime.datetime(2011, 12, 14, 0, 0), datetime.datetime(2011, 12, 18, 0, 0), -71.48, 19, 1834.37, 56837)
# (8501, 1910, 'High', 0.05, 14.48, 1.99, 3079, 'Andrew Levine', 'Regular Air', 'Consumer', 'Technology', 'Computer Peripherals', 'Small Pack', 'TDK 4.7GB DVD+RW', 0.49, 'East', 'Pennsylvania', 'Philadelphia', 19112, datetime.datetime(2012, 9, 30, 0, 0), datetime.datetime(2012, 10, 2, 0, 0), 165.2, 96, 1337.67, 13638)
# (8502, 500, 'High', 0.08, 5.98, 4.69, 3079, 'Andrew Levine', 'Regular Air', 'Consumer', 'Office Supplies', 'Storage & Organization', 'Small Box', 'Perma STOR-ALL™ Hanging File Box, 13 1/8"W x 12 1/4"D x 10 1/2"H', 0.68, 'East', 'Pennsylvania', 'Philadelphia', 19112, datetime.datetime(2012, 10, 2, 0, 0), datetime.datetime(2012, 10, 4, 0, 0), -114.18, 53, 300.78, 3460)
# (8503, 2616, 'Critical', 0.08, 2.08, 1.49, 3079, 'Andrew Levine', 'Regular Air', 'Small Business', 'Office Supplies', 'Binders and Binder Accessories', 'Small Box', 'Round Ring Binders', 0.38, 'East', 'Pennsylvania', 'Philadelphia', 19112, datetime.datetime(2013, 5, 3, 0, 0), datetime.datetime(2013, 5, 5, 0, 0), -8.3605, 18, 37.05, 18917)
# (8504, 5007, 'High', 0.1, 100.97, 7.18, 3079, 'Andrew Levine', 'Regular Air', 'Consumer', 'Technology', 'Computer Peripherals', 'Small Box', 'Gyration Ultra Cordless Optical Suite', 0.46, 'East', 'Pennsylvania', 'Philadelphia', 19112, datetime.datetime(2013, 10, 23, 0, 0), datetime.datetime(2013, 10, 24, 0, 0), 1174.02, 88, 8236.74, 35712)
# (8505, 5008, 'High', 0.0, 5.28, 8.16, 3079, 'Andrew Levine', 'Regular Air', 'Consumer', 'Office Supplies', 'Paper', 'Small Box', 'Xerox 1963', 0.4, 'East', 'Pennsylvania', 'Philadelphia', 19112, datetime.datetime(2013, 10, 23, 0, 0), datetime.datetime(2013, 10, 23, 0, 0), -122.21, 50, 281.0, 35712)
# (8506, 6695, 'Not Specified', 0.0, 83.98, 5.01, 3079, 'Andrew Levine', 'Regular Air', 'Small Business', 'Office Supplies', 'Envelopes', 'Small Box', 'Ames Color-File® Green Diamond Border X-ray Mailers', 0.38, 'East', 'Pennsylvania', 'Philadelphia', 19112, datetime.datetime(2013, 11, 16, 0, 0), datetime.datetime(2013, 11, 17, 0, 0), 1620.23, 137, 11505.26, 47682)
# (8507, 19260, 'Not Specified', 0.05, 7.99, 5.03, 3081, 'Constance Ivey', 'Regular Air', 'Home Office', 'Technology', 'Telephones and Communication', 'Medium Box', 'Bell Sonecor JB700 Caller ID', 0.6, 'South', 'Florida', 'Sarasota', 34239, datetime.datetime(2011, 8, 20, 0, 0), datetime.datetime(2011, 8, 20, 0, 0), -238.74620000000004, 19, 129.38, 89905)
# (8508, 25774, 'Low', 0.1, 32.98, 5.5, 3081, 'Constance Ivey', 'Regular Air', 'Home Office', 'Technology', 'Computer Peripherals', 'Small Box', 'PC Concepts 116 Key Quantum 3000 Keyboard', 0.75, 'South', 'Florida', 'Sarasota', 34239, datetime.datetime(2012, 10, 21, 0, 0), datetime.datetime(2012, 10, 23, 0, 0), -628.0400000000001, 20, 614.13, 89906)
# (8509, 22632, 'Low', 0.08, 270.97, 28.06, 3081, 'Constance Ivey', 'Delivery Truck', 'Home Office', 'Technology', 'Office Machines', 'Jumbo Drum', 'Epson LQ-570e Dot Matrix Printer', 0.56, 'South', 'Florida', 'Sarasota', 34239, datetime.datetime(2013, 1, 26, 0, 0), datetime.datetime(2013, 2, 2, 0, 0), -51.058, 1, 258.8, 89907)
# (8510, 22633, 'Low', 0.01, 1.6, 1.29, 3081, 'Constance Ivey', 'Regular Air', 'Home Office', 'Office Supplies', 'Pens & Art Supplies', 'Wrap Bag', 'Sanford Pocket Accent® Highlighters', 0.42, 'South', 'Florida', 'Sarasota', 34239, datetime.datetime(2013, 1, 26, 0, 0), datetime.datetime(2013, 1, 30, 0, 0), 1025.3039999999999, 12, 20.7, 89907)
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
#To bulk load data in MySQL database, we need to use mannual process which is given below:

#First to load excel file directly into database, we have to convert it into CSV file format. Then followthe steps.
#step 1 : Right click on table 
#step 2 : Select "Table Data Import Wizard"
#step 3 : Select the file which we have to load (in our case, it is SuperStore_USA.csv) and press next.
#step 4 : Select create new table and give the table name and press next.
#step 5 : Select the required conditions and press next. The data is loaded Successfully

# %%
orders
# Out:
#       RowID  OrderPriority  Discount  UnitPrice  ShippingCost  CustomerID  \
# 0     18606  Not Specified      0.01       2.88          0.50           2
# 1     20847           High      0.01       2.84          0.93           3
# 2     23086  Not Specified      0.03       6.68          6.15           3
# 3     23087  Not Specified      0.01       5.68          3.60           3
# 4     23088  Not Specified      0.00     205.99          2.50           3
# ...     ...            ...       ...        ...           ...         ...
# 9421  20275       Critical      0.06      35.89         14.72        3402
# 9422  20276       Critical      0.00       3.34          7.49        3402
# 9423  24491  Not Specified      0.08     550.98         45.70        3402
# 9424  25914           High      0.10     105.98         13.99        3403
# 9425  24492  Not Specified      0.09       7.78          2.50        3403
#
#          CustomerName        ShipMode CustomerSegment  ProductCategory  ...  \
# 0     Janice Fletcher     Regular Air       Corporate  Office Supplies  ...
# 1       Bonnie Potter     Express Air       Corporate  Office Supplies  ...
# 2       Bonnie Potter     Express Air       Corporate  Office Supplies  ...
# 3       Bonnie Potter     Regular Air       Corporate  Office Supplies  ...
# 4       Bonnie Potter     Express Air       Corporate       Technology  ...
# ...               ...             ...             ...              ...  ...
# 9421   Frederick Cole     Regular Air        Consumer  Office Supplies  ...
# 9422   Frederick Cole     Regular Air        Consumer  Office Supplies  ...
# 9423   Frederick Cole  Delivery Truck        Consumer        Furniture  ...
# 9424    Tammy Buckley     Express Air        Consumer        Furniture  ...
# 9425    Tammy Buckley     Express Air        Consumer  Office Supplies  ...
#
#        Region StateorProvince        City  PostalCode  OrderDate   ShipDate  \
# 0     Central        Illinois     Addison       60101 2012-05-28 2012-05-30
# 1        West      Washington   Anacortes       98221 2010-07-07 2010-07-08
# 2        West      Washington   Anacortes       98221 2011-07-27 2011-07-28
# 3        West      Washington   Anacortes       98221 2011-07-27 2011-07-28
# 4        West      Washington   Anacortes       98221 2011-07-27 2011-07-27
# ...       ...             ...         ...         ...        ...        ...
# 9421     East   West Virginia  Charleston       25314 2013-05-14 2013-05-15
# 9422     East   West Virginia  Charleston       25314 2013-05-14 2013-05-14
# 9423     East   West Virginia  Charleston       25314 2013-09-12 2013-09-14
# 9424     West         Wyoming    Cheyenne       82001 2010-02-08 2010-02-11
# 9425     West         Wyoming    Cheyenne       82001 2013-09-12 2013-09-14
#
#            Profit  Quantityorderednew    Sales OrderID
# 0        1.320000                   2     5.90   88525
# 1        4.560000                   4    13.01   88522
# 2      -47.640000                   7    49.92   88523
# 3      -30.510000                   7    41.64   88523
# 4      998.202300                   8  1446.67   88523
# ...           ...                 ...      ...     ...
# 9421   137.860000                  13   447.87   87532
# 9422   -39.070000                   3    13.23   87532
# 9423 -1225.029097                   4  2215.93   87533
# 9424   349.485000                   5   506.50   87530
# 9425    78.062400                  23   172.48   87533
#
# [9426 rows x 24 columns]

# %%
#3. Find out how much returns we have recieved and with a product id 
xls = pd.ExcelFile('SuperStore_USA.xlsx')
returns = pd.read_excel(xls, 'Returns',names = ["OrderID","Status"])
users = pd.read_excel(xls, 'Users')

# %%
returns
# Out:
#       OrderID    Status
# 0          65  Returned
# 1         612  Returned
# 2         614  Returned
# 3         678  Returned
# 4         710  Returned
# ...       ...       ...
# 1629   182681  Returned
# 1630   182683  Returned
# 1631   182750  Returned
# 1632   182781  Returned
# 1633   182906  Returned
#
# [1634 rows x 2 columns]

# %%
orders
# Out:
#       RowID  OrderPriority  Discount  UnitPrice  ShippingCost  CustomerID  \
# 0     18606  Not Specified      0.01       2.88          0.50           2
# 1     20847           High      0.01       2.84          0.93           3
# 2     23086  Not Specified      0.03       6.68          6.15           3
# 3     23087  Not Specified      0.01       5.68          3.60           3
# 4     23088  Not Specified      0.00     205.99          2.50           3
# ...     ...            ...       ...        ...           ...         ...
# 9421  20275       Critical      0.06      35.89         14.72        3402
# 9422  20276       Critical      0.00       3.34          7.49        3402
# 9423  24491  Not Specified      0.08     550.98         45.70        3402
# 9424  25914           High      0.10     105.98         13.99        3403
# 9425  24492  Not Specified      0.09       7.78          2.50        3403
#
#          CustomerName        ShipMode CustomerSegment  ProductCategory  ...  \
# 0     Janice Fletcher     Regular Air       Corporate  Office Supplies  ...
# 1       Bonnie Potter     Express Air       Corporate  Office Supplies  ...
# 2       Bonnie Potter     Express Air       Corporate  Office Supplies  ...
# 3       Bonnie Potter     Regular Air       Corporate  Office Supplies  ...
# 4       Bonnie Potter     Express Air       Corporate       Technology  ...
# ...               ...             ...             ...              ...  ...
# 9421   Frederick Cole     Regular Air        Consumer  Office Supplies  ...
# 9422   Frederick Cole     Regular Air        Consumer  Office Supplies  ...
# 9423   Frederick Cole  Delivery Truck        Consumer        Furniture  ...
# 9424    Tammy Buckley     Express Air        Consumer        Furniture  ...
# 9425    Tammy Buckley     Express Air        Consumer  Office Supplies  ...
#
#        Region StateorProvince        City  PostalCode  OrderDate   ShipDate  \
# 0     Central        Illinois     Addison       60101 2012-05-28 2012-05-30
# 1        West      Washington   Anacortes       98221 2010-07-07 2010-07-08
# 2        West      Washington   Anacortes       98221 2011-07-27 2011-07-28
# 3        West      Washington   Anacortes       98221 2011-07-27 2011-07-28
# 4        West      Washington   Anacortes       98221 2011-07-27 2011-07-27
# ...       ...             ...         ...         ...        ...        ...
# 9421     East   West Virginia  Charleston       25314 2013-05-14 2013-05-15
# 9422     East   West Virginia  Charleston       25314 2013-05-14 2013-05-14
# 9423     East   West Virginia  Charleston       25314 2013-09-12 2013-09-14
# 9424     West         Wyoming    Cheyenne       82001 2010-02-08 2010-02-11
# 9425     West         Wyoming    Cheyenne       82001 2013-09-12 2013-09-14
#
#            Profit  Quantityorderednew    Sales OrderID
# 0        1.320000                   2     5.90   88525
# 1        4.560000                   4    13.01   88522
# 2      -47.640000                   7    49.92   88523
# 3      -30.510000                   7    41.64   88523
# 4      998.202300                   8  1446.67   88523
# ...           ...                 ...      ...     ...
# 9421   137.860000                  13   447.87   87532
# 9422   -39.070000                   3    13.23   87532
# 9423 -1225.029097                   4  2215.93   87533
# 9424   349.485000                   5   506.50   87530
# 9425    78.062400                  23   172.48   87533
#
# [9426 rows x 24 columns]

# %%
orders_returns = pd.merge(orders, returns)

# %%
a= pd.DataFrame(orders_returns)

# %%
orders_returns.columns
# Out:
# Index(['RowID', 'OrderPriority', 'Discount', 'UnitPrice', 'ShippingCost',
#        'CustomerID', 'CustomerName', 'ShipMode', 'CustomerSegment',
#        'ProductCategory', 'ProductSub-Category', 'ProductContainer',
#        'ProductName', 'ProductBase Margin', 'Region', 'StateorProvince',
#        'City', 'PostalCode', 'OrderDate', 'ShipDate', 'Profit',
#        'Quantityorderednew', 'Sales', 'OrderID', 'Status'],
#       dtype='object')

# %%
a[(a['Status']=='Returned')]['OrderID'] #There are total 98 orders which were returned
#In the question, Product ID is mentioned which is not available, So I have given the order ID instead.
# Out:
# 0      9895
# 1     13959
# 2     13959
# 3     36038
# 4     39490
#       ...
# 93     7107
# 94     7107
# 95    42823
# 96    13638
# 97    47109
# Name: OrderID, Length: 98, dtype: int64

# %%
#4. try  to join order and return data both in sql and pandas 
pd.merge(orders, returns)

#Join in sql
#select * from returns_done INNER JOIN orders ON orders.OrderID=returns_done.orderID;
# Out:
#     RowID  OrderPriority  Discount  UnitPrice  ShippingCost  CustomerID  \
# 0    1359            Low      0.05       5.85          2.27          21
# 1    1950         Medium      0.01       4.91          0.50         117
# 2    1951         Medium      0.09       4.00          1.30         117
# 3    5055           High      0.02       3.28          5.00         117
# 4    5573            Low      0.02      11.97          5.81         272
# ..    ...            ...       ...        ...           ...         ...
# 93    986  Not Specified      0.06      37.94          5.08        3075
# 94    987  Not Specified      0.10      55.29          5.08        3075
# 95   6041         Medium      0.05       4.28          6.18        3075
# 96   1910           High      0.05      14.48          1.99        3079
# 97   6625           High      0.06     128.24         12.65        3251
#
#             CustomerName     ShipMode CustomerSegment  ProductCategory  ...  \
# 0   Tony Wilkins Winters  Regular Air  Small Business  Office Supplies  ...
# 1            Linda Weiss  Regular Air     Home Office  Office Supplies  ...
# 2            Linda Weiss  Express Air     Home Office  Office Supplies  ...
# 3            Linda Weiss  Regular Air     Home Office  Office Supplies  ...
# 4          Eleanor Swain  Regular Air  Small Business  Office Supplies  ...
# ..                   ...          ...             ...              ...  ...
# 93         Gordon Brandt  Regular Air       Corporate  Office Supplies  ...
# 94         Gordon Brandt  Regular Air       Corporate  Office Supplies  ...
# 95         Gordon Brandt  Express Air       Corporate  Office Supplies  ...
# 96         Andrew Levine  Regular Air        Consumer       Technology  ...
# 97          Peter Brooks  Regular Air  Small Business        Furniture  ...
#
#    StateorProvince           City PostalCode  OrderDate   ShipDate     Profit  \
# 0         New York  New York City      10012 2011-04-20 2011-04-24    -6.8200
# 1       Washington        Seattle      98103 2010-04-04 2010-04-06   112.0600
# 2       Washington        Seattle      98103 2010-04-04 2010-04-06    16.7900
# 3       Washington        Seattle      98103 2013-08-16 2013-08-18   -89.0600
# 4   North Carolina      Charlotte      28204 2013-08-12 2013-08-12   -81.9413
# ..             ...            ...        ...        ...        ...        ...
# 93      California    Los Angeles      90061 2013-01-04 2013-01-06   -33.9680
# 94      California    Los Angeles      90061 2013-01-04 2013-01-05   163.1200
# 95      California    Los Angeles      90061 2013-06-25 2013-06-27   -22.5600
# 96    Pennsylvania   Philadelphia      19112 2012-09-30 2012-10-02   165.2000
# 97        New York  New York City      10112 2012-09-11 2012-09-13  1844.9600
#
#    Quantityorderednew     Sales OrderID    Status
# 0                   9     54.79    9895  Returned
# 1                  47    228.46   13959  Returned
# 2                  19     77.61   13959  Returned
# 3                  52    190.52   36038  Returned
# 4                  76    912.06   39490  Returned
# ..                ...       ...     ...       ...
# 93                  3    113.14    7107  Returned
# 94                 35   1886.52    7107  Returned
# 95                 12     73.71   42823  Returned
# 96                 96   1337.67   13638  Returned
# 97                 92  12002.16   47109  Returned
#
# [98 rows x 25 columns]

# %%
#5. Try to find out how many unique customer that we have
cursor = mydb.cursor()
cursor.execute("select count(distinct CustomerID) from SuperStore.orders") #2703
print(cursor.fetchall())
cursor.close()
# Out:
# [(2703,)]
# True

# %%
total = orders['CustomerID'].unique()

# %%
len(total)
# Out:
# 2703

# %%
#6. try to find out in how many regions we are selling a product and who is a manager for a respective region 
users
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
orders.columns
# Out:
# Index(['RowID', 'OrderPriority', 'Discount', 'UnitPrice', 'ShippingCost',
#        'CustomerID', 'CustomerName', 'ShipMode', 'CustomerSegment',
#        'ProductCategory', 'ProductSub-Category', 'ProductContainer',
#        'ProductName', 'ProductBase Margin', 'Region', 'StateorProvince',
#        'City', 'PostalCode', 'OrderDate', 'ShipDate', 'Profit',
#        'Quantityorderednew', 'Sales', 'OrderID'],
#       dtype='object')

# %%
len(orders['Region'].unique()) #There are 4 regions in total and the respective managers for each region are listed in above table 'users'
# Out:
# 4

# %%
#7. find out how many different different shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset 
Shipment_mode = orders['ShipMode']

# %%
count = pd.Series(Shipment_mode).value_counts()
count
# Out:
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: ShipMode, dtype: int64

# %%
s = pd.DataFrame(count)

# %%
total_ship_mode = s.sum()

# %%
((s[['ShipMode']])/total_ship_mode)*100 #percentage usablity of all the shipment mode with respect to dataset
# Out:
#                  ShipMode
# Regular Air     74.644600
# Delivery Truck  13.611288
# Express Air     11.744112

# %%
#8. Create a new coulmn and try to find our a diffrence between order date and shipment date
orders["difference_date"] =  orders['ShipDate'] - orders['OrderDate']

# %%
orders
# Out:
#       RowID  OrderPriority  Discount  UnitPrice  ShippingCost  CustomerID  \
# 0     18606  Not Specified      0.01       2.88          0.50           2
# 1     20847           High      0.01       2.84          0.93           3
# 2     23086  Not Specified      0.03       6.68          6.15           3
# 3     23087  Not Specified      0.01       5.68          3.60           3
# 4     23088  Not Specified      0.00     205.99          2.50           3
# ...     ...            ...       ...        ...           ...         ...
# 9421  20275       Critical      0.06      35.89         14.72        3402
# 9422  20276       Critical      0.00       3.34          7.49        3402
# 9423  24491  Not Specified      0.08     550.98         45.70        3402
# 9424  25914           High      0.10     105.98         13.99        3403
# 9425  24492  Not Specified      0.09       7.78          2.50        3403
#
#          CustomerName        ShipMode CustomerSegment  ProductCategory  ...  \
# 0     Janice Fletcher     Regular Air       Corporate  Office Supplies  ...
# 1       Bonnie Potter     Express Air       Corporate  Office Supplies  ...
# 2       Bonnie Potter     Express Air       Corporate  Office Supplies  ...
# 3       Bonnie Potter     Regular Air       Corporate  Office Supplies  ...
# 4       Bonnie Potter     Express Air       Corporate       Technology  ...
# ...               ...             ...             ...              ...  ...
# 9421   Frederick Cole     Regular Air        Consumer  Office Supplies  ...
# 9422   Frederick Cole     Regular Air        Consumer  Office Supplies  ...
# 9423   Frederick Cole  Delivery Truck        Consumer        Furniture  ...
# 9424    Tammy Buckley     Express Air        Consumer        Furniture  ...
# 9425    Tammy Buckley     Express Air        Consumer  Office Supplies  ...
#
#      StateorProvince        City PostalCode  OrderDate   ShipDate  \
# 0           Illinois     Addison      60101 2012-05-28 2012-05-30
# 1         Washington   Anacortes      98221 2010-07-07 2010-07-08
# 2         Washington   Anacortes      98221 2011-07-27 2011-07-28
# 3         Washington   Anacortes      98221 2011-07-27 2011-07-28
# 4         Washington   Anacortes      98221 2011-07-27 2011-07-27
# ...              ...         ...        ...        ...        ...
# 9421   West Virginia  Charleston      25314 2013-05-14 2013-05-15
# 9422   West Virginia  Charleston      25314 2013-05-14 2013-05-14
# 9423   West Virginia  Charleston      25314 2013-09-12 2013-09-14
# 9424         Wyoming    Cheyenne      82001 2010-02-08 2010-02-11
# 9425         Wyoming    Cheyenne      82001 2013-09-12 2013-09-14
#
#            Profit Quantityorderednew    Sales OrderID difference_date
# 0        1.320000                  2     5.90   88525          2 days
# 1        4.560000                  4    13.01   88522          1 days
# 2      -47.640000                  7    49.92   88523          1 days
# 3      -30.510000                  7    41.64   88523          1 days
# 4      998.202300                  8  1446.67   88523          0 days
# ...           ...                ...      ...     ...             ...
# 9421   137.860000                 13   447.87   87532          1 days
# 9422   -39.070000                  3    13.23   87532          0 days
# 9423 -1225.029097                  4  2215.93   87533          2 days
# 9424   349.485000                  5   506.50   87530          3 days
# 9425    78.062400                 23   172.48   87533          2 days
#
# [9426 rows x 25 columns]

# %%
#9. Based on Question number 8, find out for which order id we have shipment duration more than 10 days 
difference = orders['difference_date']

# %%
orders[(orders['difference_date'].dt.components['days']>10)]
# Out:
#       RowID  OrderPriority  Discount  UnitPrice  ShippingCost  CustomerID  \
# 643   18246       Critical      0.05      11.09          5.25         250
# 1548  23091         Medium      0.04     100.98          7.18         595
# 1549  23092         Medium      0.09       6.48          7.49         595
# 1678  20703  Not Specified      0.07     130.98         30.00         637
# 1679  20704  Not Specified      0.09      55.98          4.86         637
# 1680  20705  Not Specified      0.08     115.99          4.23         637
# 1697   2703  Not Specified      0.07     130.98         30.00         640
# 1698   2704  Not Specified      0.09      55.98          4.86         640
# 1699   2705  Not Specified      0.08     115.99          4.23         640
# 2515  18060            Low      0.02       2.21          1.00         964
# 5548  21603  Not Specified      0.02       5.58          1.99        2048
# 5673  19005            Low      0.06      65.99          2.50        2088
# 5859  24392            Low      0.05      29.89          1.99        2143
# 5881  21257            Low      0.05       7.99          5.03        2153
# 8607  26351         Medium      0.00       8.32          2.38        3119
# 8609  26350         Medium      0.07     180.98         55.24        3119
# 8610  26352         Medium      0.06       4.20          2.26        3119
# 8973  20750            Low      0.06     125.99          8.08        3248
# 8982   2748            Low      0.03      11.97          5.81        3251
# 8983   2749            Low      0.08     195.99          4.20        3251
# 8993   2750            Low      0.06     125.99          8.08        3251
# 8996  20748            Low      0.03      11.97          5.81        3252
# 8997  20749            Low      0.08     195.99          4.20        3252
#
#                  CustomerName        ShipMode CustomerSegment  \
# 643   Brenda Nelson Blanchard     Regular Air       Corporate
# 1548               Dana Desai     Regular Air  Small Business
# 1549               Dana Desai     Express Air  Small Business
# 1678       Christopher Bryant  Delivery Truck        Consumer
# 1679       Christopher Bryant     Regular Air        Consumer
# 1680       Christopher Bryant     Regular Air        Consumer
# 1697               Neal Wolfe  Delivery Truck        Consumer
# 1698               Neal Wolfe     Regular Air        Consumer
# 1699               Neal Wolfe     Regular Air        Consumer
# 2515          Virginia Rivera     Regular Air     Home Office
# 5548          Ricky Dougherty     Regular Air        Consumer
# 5673             Carrie Boyle     Regular Air       Corporate
# 5859            Lester Sawyer     Regular Air     Home Office
# 5881               Anna Glenn     Regular Air     Home Office
# 8607              Jay Hubbard     Express Air       Corporate
# 8609              Jay Hubbard  Delivery Truck       Corporate
# 8610              Jay Hubbard     Regular Air       Corporate
# 8973            Earl Donnelly     Express Air       Corporate
# 8982             Peter Brooks     Regular Air       Corporate
# 8983             Peter Brooks     Regular Air       Corporate
# 8993             Peter Brooks     Express Air       Corporate
# 8996           Milton Harrell     Regular Air       Corporate
# 8997           Milton Harrell     Regular Air       Corporate
#
#       ProductCategory  ... StateorProvince           City PostalCode  \
# 643   Office Supplies  ...       Minnesota      Richfield      55423
# 1548       Technology  ...         Indiana    Bloomington      47401
# 1549  Office Supplies  ...         Indiana    Bloomington      47401
# 1678        Furniture  ...      California    Santa Clara      95051
# 1679  Office Supplies  ...      California    Santa Clara      95051
# 1680       Technology  ...      California    Santa Clara      95051
# 1697        Furniture  ...      Washington        Seattle      98119
# 1698  Office Supplies  ...      Washington        Seattle      98119
# 1699       Technology  ...      Washington        Seattle      98119
# 2515  Office Supplies  ...      California   Redwood City      94061
# 5548  Office Supplies  ...    South Dakota      Brookings      57006
# 5673       Technology  ...        New York   Mount Vernon      10550
# 5859       Technology  ...        Virginia        Fairfax      20151
# 5881       Technology  ...      California       Pasadena      91104
# 8607       Technology  ...         Florida        Orlando      32839
# 8609  Office Supplies  ...         Florida        Orlando      32839
# 8610  Office Supplies  ...         Florida        Orlando      32839
# 8973       Technology  ...       Louisiana        Slidell      70458
# 8982  Office Supplies  ...        New York  New York City      10112
# 8983       Technology  ...        New York  New York City      10112
# 8993       Technology  ...        New York  New York City      10112
# 8996  Office Supplies  ...        New York      Rotterdam      12306
# 8997       Technology  ...        New York      Rotterdam      12306
#
#       OrderDate   ShipDate     Profit Quantityorderednew     Sales OrderID  \
# 643  2011-12-29 2012-03-22    58.5000                 19    204.67   87215
# 1548 2011-12-30 2012-01-10   375.7050                  6    587.46   86318
# 1549 2011-12-30 2012-01-14   -47.3950                 12     79.37   86318
# 1678 2011-12-30 2012-01-16  -211.8850                 21   2699.94   87957
# 1679 2011-12-30 2012-01-10   355.0119                 10    514.51   87957
# 1680 2011-12-30 2012-01-27  1021.4001                 16   1480.29   87957
# 1697 2011-12-30 2012-01-16  -423.7700                 83  10671.20   19556
# 1698 2011-12-30 2012-01-10   469.6900                 41   2109.51   19556
# 1699 2011-12-30 2012-01-27   727.3620                 65   6013.69   19556
# 2515 2011-12-30 2012-03-31     5.8200                 10     22.35   86177
# 5548 2011-12-30 2012-01-13    66.2250                 21    121.51   88223
# 5673 2011-12-28 2012-01-14   187.4880                  8    451.34   88352
# 5859 2011-12-26 2012-01-17  4230.2001                 12    344.16   87572
# 5881 2011-12-26 2012-01-19   -23.4520                  2     15.56   91294
# 8607 2011-12-29 2012-01-16 -1075.3960                 19    170.62   86434
# 8609 2013-12-29 2014-01-15  -147.5180                 25   4529.95   86436
# 8610 2013-12-29 2014-01-17  -689.8738                  2      9.64   86436
# 8973 2011-12-26 2012-01-14     2.4780                 20   2180.31   87300
# 8982 2011-12-26 2012-01-22   -31.7400                 31    388.52   19841
# 8983 2011-12-26 2012-01-26  -557.9530                 13   2092.05   19841
# 8993 2013-12-26 2014-01-14  1304.5590                 86   9375.35   19841
# 8996 2011-12-26 2012-01-22   -15.8700                  8    100.26   87300
# 8997 2011-12-26 2012-01-26  -278.9765                  3    482.78   87300
#
#      difference_date
# 643          84 days
# 1548         11 days
# 1549         15 days
# 1678         17 days
# 1679         11 days
# 1680         28 days
# 1697         17 days
# 1698         11 days
# 1699         28 days
# 2515         92 days
# 5548         14 days
# 5673         17 days
# 5859         22 days
# 5881         24 days
# 8607         18 days
# 8609         17 days
# 8610         19 days
# 8973         19 days
# 8982         27 days
# 8983         31 days
# 8993         19 days
# 8996         27 days
# 8997         31 days
#
# [23 rows x 25 columns]

# %%
orders[(orders['difference_date'].dt.components['days']>10)]['OrderID']
# Out:
# 643     87215
# 1548    86318
# 1549    86318
# 1678    87957
# 1679    87957
# 1680    87957
# 1697    19556
# 1698    19556
# 1699    19556
# 2515    86177
# 5548    88223
# 5673    88352
# 5859    87572
# 5881    91294
# 8607    86434
# 8609    86436
# 8610    86436
# 8973    87300
# 8982    19841
# 8983    19841
# 8993    19841
# 8996    87300
# 8997    87300
# Name: OrderID, dtype: int64

# %%
#10. Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well 
all_data = pd.concat([orders,returns])

# %%
pd.merge()

# %%
orders.join(df11, how = 'right')

# %%
all_data.columns
# Out:
# Index(['RowID', 'OrderPriority', 'Discount', 'UnitPrice', 'ShippingCost',
#        'CustomerID', 'CustomerName', 'ShipMode', 'CustomerSegment',
#        'ProductCategory', 'ProductSub-Category', 'ProductContainer',
#        'ProductName', 'ProductBase Margin', 'Region', 'StateorProvince',
#        'City', 'PostalCode', 'OrderDate', 'ShipDate', 'Profit',
#        'Quantityorderednew', 'Sales', 'OrderID', 'difference_date', 'Status'],
#       dtype='object')

# %%
all_data[(all_data['difference_date'].dt.components['days']>15)]
# Out:
#         RowID  OrderPriority  Discount  UnitPrice  ShippingCost  CustomerID  \
# 643   18246.0       Critical      0.05      11.09          5.25       250.0
# 1678  20703.0  Not Specified      0.07     130.98         30.00       637.0
# 1680  20705.0  Not Specified      0.08     115.99          4.23       637.0
# 1697   2703.0  Not Specified      0.07     130.98         30.00       640.0
# 1699   2705.0  Not Specified      0.08     115.99          4.23       640.0
# 2515  18060.0            Low      0.02       2.21          1.00       964.0
# 5673  19005.0            Low      0.06      65.99          2.50      2088.0
# 5859  24392.0            Low      0.05      29.89          1.99      2143.0
# 5881  21257.0            Low      0.05       7.99          5.03      2153.0
# 8607  26351.0         Medium      0.00       8.32          2.38      3119.0
# 8609  26350.0         Medium      0.07     180.98         55.24      3119.0
# 8610  26352.0         Medium      0.06       4.20          2.26      3119.0
# 8973  20750.0            Low      0.06     125.99          8.08      3248.0
# 8982   2748.0            Low      0.03      11.97          5.81      3251.0
# 8983   2749.0            Low      0.08     195.99          4.20      3251.0
# 8993   2750.0            Low      0.06     125.99          8.08      3251.0
# 8996  20748.0            Low      0.03      11.97          5.81      3252.0
# 8997  20749.0            Low      0.08     195.99          4.20      3252.0
#
#                  CustomerName        ShipMode CustomerSegment  \
# 643   Brenda Nelson Blanchard     Regular Air       Corporate
# 1678       Christopher Bryant  Delivery Truck        Consumer
# 1680       Christopher Bryant     Regular Air        Consumer
# 1697               Neal Wolfe  Delivery Truck        Consumer
# 1699               Neal Wolfe     Regular Air        Consumer
# 2515          Virginia Rivera     Regular Air     Home Office
# 5673             Carrie Boyle     Regular Air       Corporate
# 5859            Lester Sawyer     Regular Air     Home Office
# 5881               Anna Glenn     Regular Air     Home Office
# 8607              Jay Hubbard     Express Air       Corporate
# 8609              Jay Hubbard  Delivery Truck       Corporate
# 8610              Jay Hubbard     Regular Air       Corporate
# 8973            Earl Donnelly     Express Air       Corporate
# 8982             Peter Brooks     Regular Air       Corporate
# 8983             Peter Brooks     Regular Air       Corporate
# 8993             Peter Brooks     Express Air       Corporate
# 8996           Milton Harrell     Regular Air       Corporate
# 8997           Milton Harrell     Regular Air       Corporate
#
#       ProductCategory  ...           City PostalCode  OrderDate   ShipDate  \
# 643   Office Supplies  ...      Richfield    55423.0 2011-12-29 2012-03-22
# 1678        Furniture  ...    Santa Clara    95051.0 2011-12-30 2012-01-16
# 1680       Technology  ...    Santa Clara    95051.0 2011-12-30 2012-01-27
# 1697        Furniture  ...        Seattle    98119.0 2011-12-30 2012-01-16
# 1699       Technology  ...        Seattle    98119.0 2011-12-30 2012-01-27
# 2515  Office Supplies  ...   Redwood City    94061.0 2011-12-30 2012-03-31
# 5673       Technology  ...   Mount Vernon    10550.0 2011-12-28 2012-01-14
# 5859       Technology  ...        Fairfax    20151.0 2011-12-26 2012-01-17
# 5881       Technology  ...       Pasadena    91104.0 2011-12-26 2012-01-19
# 8607       Technology  ...        Orlando    32839.0 2011-12-29 2012-01-16
# 8609  Office Supplies  ...        Orlando    32839.0 2013-12-29 2014-01-15
# 8610  Office Supplies  ...        Orlando    32839.0 2013-12-29 2014-01-17
# 8973       Technology  ...        Slidell    70458.0 2011-12-26 2012-01-14
# 8982  Office Supplies  ...  New York City    10112.0 2011-12-26 2012-01-22
# 8983       Technology  ...  New York City    10112.0 2011-12-26 2012-01-26
# 8993       Technology  ...  New York City    10112.0 2013-12-26 2014-01-14
# 8996  Office Supplies  ...      Rotterdam    12306.0 2011-12-26 2012-01-22
# 8997       Technology  ...      Rotterdam    12306.0 2011-12-26 2012-01-26
#
#          Profit Quantityorderednew     Sales  OrderID difference_date Status
# 643     58.5000               19.0    204.67    87215         84 days    NaN
# 1678  -211.8850               21.0   2699.94    87957         17 days    NaN
# 1680  1021.4001               16.0   1480.29    87957         28 days    NaN
# 1697  -423.7700               83.0  10671.20    19556         17 days    NaN
# 1699   727.3620               65.0   6013.69    19556         28 days    NaN
# 2515     5.8200               10.0     22.35    86177         92 days    NaN
# 5673   187.4880                8.0    451.34    88352         17 days    NaN
# 5859  4230.2001               12.0    344.16    87572         22 days    NaN
# 5881   -23.4520                2.0     15.56    91294         24 days    NaN
# 8607 -1075.3960               19.0    170.62    86434         18 days    NaN
# 8609  -147.5180               25.0   4529.95    86436         17 days    NaN
# 8610  -689.8738                2.0      9.64    86436         19 days    NaN
# 8973     2.4780               20.0   2180.31    87300         19 days    NaN
# 8982   -31.7400               31.0    388.52    19841         27 days    NaN
# 8983  -557.9530               13.0   2092.05    19841         31 days    NaN
# 8993  1304.5590               86.0   9375.35    19841         19 days    NaN
# 8996   -15.8700                8.0    100.26    87300         27 days    NaN
# 8997  -278.9765                3.0    482.78    87300         31 days    NaN
#
# [18 rows x 26 columns]

# %%
orders.columns
# Out:
# Index(['RowID', 'OrderPriority', 'Discount', 'UnitPrice', 'ShippingCost',
#        'CustomerID', 'CustomerName', 'ShipMode', 'CustomerSegment',
#        'ProductCategory', 'ProductSub-Category', 'ProductContainer',
#        'ProductName', 'ProductBase Margin', 'Region', 'StateorProvince',
#        'City', 'PostalCode', 'OrderDate', 'ShipDate', 'Profit',
#        'Quantityorderednew', 'Sales', 'OrderID', 'difference_date'],
#       dtype='object')

# %%
#11. Group by region and find out which region is most profitable 
orders.groupby(['Region'])['Profit'].aggregate('count').reset_index().sort_values("Profit",ascending = True)
# Out:
#     Region  Profit
# 2    South    1954
# 3     West    2284
# 1     East    2289
# 0  Central    2899

# %%
orders.groupby(['Region'])['Profit'].aggregate('count').reset_index().sort_values("Profit",ascending = True).max() #West Region is most Profitable
# Out:
# Region    West
# Profit    2899
# dtype: object

# %%
orders['Discount'].unique()
# Out:
# array([0.01, 0.03, 0.  , 0.09, 0.08, 0.02, 0.07, 0.1 , 0.05, 0.06, 0.04,
#        0.11, 0.17, 0.16, 0.25, 0.21])

# %%
#12. Try to find out overall in which country we are giving more discount 
[orders[orders['Discount']>0.1]['Region']] #In central region, we are giving the most discounts.
# Out:
# [5990    Central
#  5991    Central
#  6000    Central
#  8649    Central
#  8661    Central
#  Name: Region, dtype: object]

# %%
orders.columns
# Out:
# Index(['RowID', 'OrderPriority', 'Discount', 'UnitPrice', 'ShippingCost',
#        'CustomerID', 'CustomerName', 'ShipMode', 'CustomerSegment',
#        'ProductCategory', 'ProductSub-Category', 'ProductContainer',
#        'ProductName', 'ProductBase Margin', 'Region', 'StateorProvince',
#        'City', 'PostalCode', 'OrderDate', 'ShipDate', 'Profit',
#        'Quantityorderednew', 'Sales', 'OrderID', 'difference_date'],
#       dtype='object')

# %%
#13. Give me a list of unique postal code 
orders['PostalCode'].unique()
# Out:
# array([60101, 98221, 91776, ..., 61832, 62521, 26554], dtype=int64)

# %%
orders[orders["Profit"]>100].nunique()
# Out:
# RowID                  2635
# OrderPriority             5
# Discount                 12
# UnitPrice               522
# ShippingCost            403
# CustomerID             1579
# CustomerName           1579
# ShipMode                  3
# CustomerSegment           4
# ProductCategory           3
# ProductSub-Category      17
# ProductContainer          7
# ProductName             775
# ProductBase Margin       51
# Region                    4
# StateorProvince          49
# City                   1106
# PostalCode             1278
# OrderDate              1084
# ShipDate               1136
# Profit                 2584
# Quantityorderednew       99
# Sales                  2619
# OrderID                2318
# difference_date          15
# dtype: int64

# %%
#14 . which customer segement is more profitable find it out . 
orders.groupby(['CustomerSegment'])['Profit'].aggregate('count') #The corporate Customer segment is more profitable than others
# Out:
# CustomerSegment
# Consumer          1894
# Corporate         3375
# Home Office       2316
# Small Business    1841
# Name: Profit, dtype: int64

# %%
#15. try to find out the 10th most loss making product catagory . 
orders[orders['Profit']<0].reset_index().sort_values('Profit', ascending = True).head(10)
# Out:
#       index  RowID  OrderPriority  Discount  UnitPrice  ShippingCost  \
# 2291   4659  18306         Medium      0.08     175.99          4.99
# 2121   4338  20972            Low      0.01      24.95          2.99
# 3811   7800  23213            Low      0.09    6783.02         24.49
# 2381   4844  21284       Critical      0.04     880.98         44.55
# 2660   5402  24076         Medium      0.04    6783.02         24.49
# 2664   5409  22942           High      0.05    3502.14          8.73
# 3771   7725  21048  Not Specified      0.06    6783.02         24.49
# 1061   2191  21575  Not Specified      0.05    3499.99         24.49
# 1977   4068  21917           High      0.06    3502.14          8.73
# 2387   4857  24251           High      0.05    3502.14          8.73
#
#       CustomerID          CustomerName        ShipMode CustomerSegment  ...  \
# 2291        1738          Dean Solomon     Regular Air       Corporate  ...
# 2121        1632            Lori Wolfe     Regular Air     Home Office  ...
# 3811        2855          Vicki Womble     Regular Air        Consumer  ...
# 2381        1793        Derek Jernigan  Delivery Truck     Home Office  ...
# 2660        2004  James Dickinson Ball     Regular Air     Home Office  ...
# 2664        2006          Cynthia Khan  Delivery Truck     Home Office  ...
# 3771        2825          Carole Rosen     Regular Air        Consumer  ...
# 1061         838           Gary Walton     Regular Air        Consumer  ...
# 1977        1530          Seth Sweeney  Delivery Truck        Consumer  ...
# 2387        1796        Carlos Johnson  Delivery Truck       Corporate  ...
#
#      StateorProvince              City PostalCode  OrderDate   ShipDate  \
# 2291  North Carolina          Gastonia      28052 2010-03-28 2010-03-28
# 2121     Mississippi       Hattiesburg      39401 2012-05-21 2012-05-21
# 3811      Washington        Des Moines      98198 2010-03-10 2010-03-14
# 2381        Illinois         Galesburg      61401 2010-01-06 2010-01-07
# 2660         Montana           Bozeman      59715 2010-10-17 2010-10-19
# 2664        Colorado           Durango      81301 2011-01-18 2011-01-19
# 3771           Idaho             Boise      83701 2011-09-12 2011-09-14
# 1061      California  Hacienda Heights      91745 2013-10-02 2013-10-03
# 1977      California      Palm Springs      92262 2012-07-07 2012-07-09
# 2387      California     San Francisco      94110 2013-03-23 2013-03-24
#
#             Profit Quantityorderednew    Sales  OrderID difference_date
# 2291 -16476.838000                 10  1486.34    85865          0 days
# 2121 -14369.123580                  3    81.31    90534          0 days
# 3811 -14140.701600                  1  6296.00    87317          4 days
# 2381 -13706.464000                  8  6968.90    87853          1 days
# 2660 -13562.637408                  1  6569.07    91277          2 days
# 2664 -10402.943916                  1  3460.11    88799          1 days
# 3771 -10263.659700                  2  9507.12    89498          2 days
# 1061  -9078.940000                  2  6849.48    89896          1 days
# 1977  -8570.448300                  1  3057.44    88853          2 days
# 2387  -7961.430900                  1  3360.30    90778          1 days
#
# [10 rows x 26 columns]

# %%
(orders.sort_values('Profit', ascending = True)).reset_index().iloc[[9]]
# Out:
#    index  RowID OrderPriority  Discount  UnitPrice  ShippingCost  CustomerID  \
# 9   4857  24251          High      0.05    3502.14          8.73        1796
#
#      CustomerName        ShipMode CustomerSegment  ... StateorProvince  \
# 9  Carlos Johnson  Delivery Truck       Corporate  ...      California
#
#             City PostalCode  OrderDate   ShipDate     Profit  \
# 9  San Francisco      94110 2013-03-23 2013-03-24 -7961.4309
#
#   Quantityorderednew   Sales  OrderID difference_date
# 9                  1  3360.3    90778          1 days
#
# [1 rows x 26 columns]

# %%
#16. Try to find out 10 top  product with highest margins 
orders.sort_values(['ProductBase Margin'])['ProductName'].head(10)
# Out:
# 2431              GBC DocuBind 200 Manual Binding Machine
# 8248       Peel & Seel® Recycled Catalog Envelopes, Brown
# 1515       Peel & Seel® Recycled Catalog Envelopes, Brown
# 5050       Peel & Seel® Recycled Catalog Envelopes, Brown
# 413                                           Accessory31
# 5034                          Prang Dustless Chalk Sticks
# 8308         Staples Brown Kraft Recycled Clasp Envelopes
# 8311     Storex DuraTech Recycled Plastic Frosted Binders
# 8318                                          Accessory31
# 1553    Adams Telephone Message Book w/Frequently-Call...
# Name: ProductName, dtype: object
